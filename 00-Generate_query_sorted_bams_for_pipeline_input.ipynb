# %% [markdown]
# ## Testing Variant callers

# %% [markdown]
# Here we test GATK, Sentieon, and Dragen variant callers to determine what the best mehod for variant calling is in terms of precision and sensitivity

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import re, json, os, logging, io, pprint, subprocess, requests

import pandas as pd

import vcf

from cromwell_tools.cromwell_api import CromwellAPI as cwt
from cromwell_tools import cromwell_auth
from google.cloud import storage

import cromwell_functions
from cromwell_functions import defaultCromwellRunner

# %%
auth_obj = cromwell_auth.CromwellAuth(url = "http://34.69.50.44:8000", header= None, auth = None)
auth_obj
# Out:
# You are not using any authentication with Cromwell. For security purposes, please consider adding authentication in front of your Cromwell instance!

# %%
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = "/home/rcarter/.google/bioskryb-81ce35d92471.json"

# %%
storage_client = storage.Client('bioskryb')

# %% [markdown]
# ## GATK - with Ref

# %% [markdown]
# Here we perform joint genotyping on 16 samples from lots 16 - 20. The samples are not subsampled, but are all similar in file size.
# We first run the GATK gVCFs through GATK's haplotypeCaller, but including the subsampled Bulk2 reference sequence.

# %%
gvcf_filenames = !gsutil ls gs://bioskryb-vumc-data/Full_PTA_exome_deepdive_with_other_techs/data/01-gatk_cromwell_output/**.g.vcf.gz
gvcf_filenames_n16 = [_file for _file in gvcf_filenames if re.sub(".g.vcf.gz", "", os.path.basename(_file)) in non_subsampled_sample_names] + ["gs://bioskryb-cromwell-outputs-jd7fh2/temp-folder-for-deletion/NA12878_Bulk2_merged_n450x10e6.g.vcf.gz"]

# %%
df_list = [[re.sub("(.g.vcf.gz)|(_merged.+)", "", os.path.basename(_blobname)), _blobname] for _blobname in gvcf_filenames_n16]
pd.DataFrame(df_list).to_csv('tracked_data/gatk_n16_nonsubsampled_sample_map.tsv', sep = "\t", header = False, index= False)
# !gsutil cp tracked_data/gatk_n16_nonsubsampled_sample_map.tsv gs://bioskryb-work-d8f6s9/ComparingGatkSentieonDRAGEN/data/04-nosubsampling_n16_joint_genotyping/

# %%
jj_input_json = cromwell_functions.download_and_read_inputs_json("gs://bioskryb_dev_wdl_and_inputs/gatk-workflows/gatk4-germline-snps-indels/2.0.0/JointGenotyping.hg38.wgs.inputs.json", storage_client)

# %%
jj_input_json['JointGenotyping.sample_name_map'] = "gs://bioskryb-work-d8f6s9/ComparingGatkSentieonDRAGEN/data/04-nosubsampling_n16_joint_genotyping/gatk_n16_nonsubsampled_sample_map.tsv"
jj_input_json['JointGenotyping.callset_name'] = "nosubsampling_n16_gatk_joint_genotyping_gatk"

# %%
project_name = "ComparingGatkSentieonDRAGEN"
final_output_bucket = "gs://bioskryb-work-d8f6s9"
cromwell_runs_bucket = "gs://bioskryb-dev-cromwell-runs-8dhf5d"

    
output_base_location = "{}/{}/{}".format(final_output_bucket, project_name, "04-nosubsampling_n16_joint_genotyping")
jj_options_dict = {
        "read_from_cache": False,
        "default_runtime_attributes": {
                "zones": "us-central1-a us-central1-b us-central1-c us-central1-f"
        },
        "final_workflow_outputs_dir": output_base_location,
        "use_relative_output_paths": True,
        "final_call_logs_dir": "{}/call_logs".format(output_base_location),
        "jes_gcs_root": cromwell_runs_bucket,
        "google_labels": {
                "pipeline-name": "gatk4-germline-snps-indels",
                "project-name": "comparing-gatk-sentieon-dragen"
        }
}

# %%
input_iobytes = io.BytesIO(json.dumps(jj_input_json).encode())
options_iobytes = io.BytesIO(json.dumps(jj_options_dict).encode())
jj_resp = cwt.submit(auth_obj, 
       wdl_file = cromwell_functions.get_wdl_iobytes("gs://bioskryb_dev_wdl_and_inputs/gatk-workflows/gatk4-germline-snps-indels/2.0.0/JointGenotyping.wdl", storage_client), 
       inputs_files = input_iobytes,
       options_file = options_iobytes
)

# %%
jj_resp.content

# %%
gvcf_filenames_n16

# %% [markdown]
# ## Sentieon - gVCF generation

# %% [markdown]
# The same 16 samples from above (plus the reference) are joint genotyped using Sentieon

# %% [markdown]
# First, generate gVCFs

# %%
r1_fastq_files = !gsutil ls gs://bioskryb-vumc-data/Nova181_H2VMKDSXY/*_R1_*fastq.gz
r2_fastq_files = !gsutil ls gs://bioskryb-vumc-data/Nova182_H2VGNDSXY/*_R1_*fastq.gz
all_r1_fastqs = r1_fastq_files + r2_fastq_files

# %%
all_r1_fastqs
valid_fastq_r1_filenames_n16 = [_file for _file in all_r1_fastqs if re.sub("_S[01-9].*.fastq.gz", "", os.path.basename(_file)) in non_subsampled_sample_names] + ["gs://bioskryb-work-d8f6s9/ComparingGatkSentieonDRAGEN/data/NA12878_Bulk2_merged_n450x10e6_R1_001.fastq.gz"]
valid_fastq_r1_filenames_n16 = sorted(valid_fastq_r1_filenames_n16)

# %%
sample_to_fastq_dict = {}
for _file in valid_fastq_r1_filenames_n16:
    sample_name = re.sub("_S[01-9].*.fastq.gz", "", os.path.basename(_file))
    try:
        sample_to_fastq_dict[sample_name].append(_file)
    except:
        sample_to_fastq_dict[sample_name] = [_file]

# %%
sentieon_input_dict = {
  "FQ1": "",
  "FQ2": "",
  "REF": "gs://bioskryb-dev-resources-4j2g6d/Homo_sapiens_assembly38.fasta",
  "READGROUP": "",
  "OUTPUT_BUCKET": "gs://bioskryb-work-d8f6s9/ComparingGatkSentieonDRAGEN/data/03-joint_genotyping_input_gvcfs/sentieon/{}",
  "BQSR_SITES": "gs://bioskryb-dev-resources-4j2g6d/Mills_and_1000G_gold_standard.indels.hg38.vcf.gz,gs://bioskryb-dev-resources-4j2g6d/Homo_sapiens_assembly38.known_indels.vcf.gz,gs://bioskryb-dev-resources-4j2g6d/Homo_sapiens_assembly38.dbsnp138.vcf.gz",
  "DBSNP": "gs://bioskryb-dev-resources-4j2g6d/Homo_sapiens_assembly38.dbsnp138.vcf.gz",
  "GVCF_OUTPUT": "true",
  "PREEMPTIBLE_TRIES": "2",
  "NONPREEMPTIBLE_TRY": True,
  "STREAM_INPUT": "True",
  "ZONES": "us-central1-a,us-central1-b,us-central1-c,us-central1-f",
  "PROJECT_ID": "bioskryb",
  "EMAIL": "rob.carter@bioskryb.com"
}

# %%
for _sample_name, file_list in sample_to_fastq_dict.items():
    rg_list = []
    for _i in range(len(file_list)):
        rg_list.append("@RG\\tID:rgid-{}\\tSM:{}\\tPL:ILLUMINA".format(_i, _sample_name))
    rg = ",".join(rg_list)
    fq1 = ",".join(file_list)
    fq2 = re.sub("_R1_", "_R2_", ",".join(file_list))
    new_input_dict = deepcopy(sentieon_input_dict)
    new_input_dict['OUTPUT_BUCKET'] = sentieon_input_dict['OUTPUT_BUCKET'].format(_sample_name)
    new_input_dict['FQ1'] = fq1
    new_input_dict['FQ2'] = fq2
    new_input_dict['READGROUP'] = rg
    json_filename = "tracked_data/{}.n16.sentieoninput.json".format(_sample_name)
    with open(json_filename, 'w') as ofh:
        json.dump(new_input_dict, ofh)

# %%
# %%writefile tracked_data/time_and_run_sentieon.sh
# #!/usr/bin/env bash
# JSON_FILE=$1
# LOG_FILE=${JSON_FILE}.run.log
# echo Start: $(date +'%m-%d-%Y-%H-%M-%S') > $LOG_FILE
# echo Running: ~/sentieon-google-genomics/runner/sentieon_runner.py $JSON_FILE
# echo $(~/sentieon-google-genomics/runner/sentieon_runner.py $JSON_FILE) >> $LOG_FILE
# echo End: $(date +'%m-%d-%Y-%H-%M-%S') >> $LOG_FILE

# %%
# !chmod 755 tracked_data/time_and_run_sentieon.sh

# %%
json_files = !ls tracked_data/*.n16.sentieoninput.json
json_files

# %%
# !ls tracked_data/*JW-32.n16.sentieoninput.json | parallel -j 16 --max-args 1 "tracked_data/time_and_run_sentieon.sh {}"

# %%
options_dict = {
        "default_runtime_attributes": {
                "zones": "us-central1-a us-central1-b us-central1-c us-central1-f",
                "noAddress": False,
                "bootDiskSizeGb": 60
        },
}

# %%
default_inputs_dict = requests.get("https://raw.githubusercontent.com/gatk-workflows/generic-wdl-script/master/generic-workflow.input.json").json()
ref_sequence = "gs://bioskryb-dev-resources-4j2g6d/Homo_sapiens_assembly38.fasta"
ref_sequence_index = "gs://bioskryb-dev-resources-4j2g6d/Homo_sapiens_assembly38.fasta.fai"
dbsnp_filename = "gs://bioskryb-dev-resources-4j2g6d/Homo_sapiens_assembly38.dbsnp138.vcf.gz"
dbsnp_index = filename = "gs://bioskryb-dev-resources-4j2g6d/Homo_sapiens_assembly38.dbsnp138.vcf.gz.tbi"
local_dbsnp_filename = os.path.basename(dbsnp_filename)
local_ref = os.path.basename(ref_sequence)
local_ref_index = os.path.basename(ref_sequence_index)

bam = "gs://bioskryb-work-d8f6s9/ComparingGatkSentieonDRAGEN/data/03-joint_genotyping_input_gvcfs/sentieon/4249-JW-32/aligned_reads/dedup.bam"
bai = "gs://bioskryb-work-d8f6s9/ComparingGatkSentieonDRAGEN/data/03-joint_genotyping_input_gvcfs/sentieon/4249-JW-32/aligned_reads/dedup.bam.bai"
recal = "gs://bioskryb-work-d8f6s9/ComparingGatkSentieonDRAGEN/data/03-joint_genotyping_input_gvcfs/sentieon/4249-JW-32/aligned_reads/recal_data.table"

haplotyper_command = "sentieon driver -t 64 -r {ref} -i {bam} -q {recal} --algo Haplotyper -d {dbsnp} --emit_mode gvcf 4249-JW-32_hc.g.vcf.gz && mv 4249-JW-32_hc.g.vcf.gz* ./output/".format(ref = os.path.basename(ref_sequence),  bam = os.path.basename(bam), recal = os.path.basename(recal), dbsnp = os.path.basename(dbsnp_filename))

wdl_iobytes = io.BytesIO(requests.get("https://raw.githubusercontent.com/gatk-workflows/generic-wdl-script/master/generic-workflow.wdl").text.encode())
new_sentieon_inputs_dict = deepcopy(default_inputs_dict)
new_sentieon_inputs_dict["genericworkflow.GenericTask.shell_command"] = haplotyper_command
new_sentieon_inputs_dict["genericworkflow.GenericTask.input_files"] =[ref_sequence, ref_sequence_index, dbsnp_filename, dbsnp_filename_index, bam, bai, recal]
new_sentieon_inputs_dict["genericworkflow.docker_override"] = "gcr.io/bioskryb/sentieon-201911:latest"
new_sentieon_inputs_dict["genericworkflow.GenericTask.machine_mem_gb"] = 84
new_sentieon_inputs_dict["genericworkflow.GenericTask.disk_space_gb"] = 400
new_sentieon_inputs_dict["genericworkflow.GenericTask.cpu"] = 64
wdl_sentieon_inputs_iobytes = io.BytesIO(json.dumps(new_sentieon_inputs_dict).encode())
temp_sentieon_resp = cwt.submit(auth = auth_obj, wdl_file=wdl_iobytes, inputs_files=wdl_sentieon_inputs_iobytes, options_file= io.BytesIO(json.dumps(options_dict).encode()))

# %%
temp_sentieon_resp.content

# %% [markdown]
# ### Sentieon - Joint-genotyping

# %%
gvcf_sentieon_filenames = !gsutil ls gs://bioskryb-work-d8f6s9/ComparingGatkSentieonDRAGEN/data/03-joint_genotyping_input_gvcfs/sentieon/variants/**.g.vcf.gz
gvcf_sentieon_filenames_n16 = gvcf_sentieon_filenames
gvcf_sentieon_filenames_n16

# %%
len(gvcf_sentieon_filenames_n16)

# %%
project_name = "ComparingGatkSentieonDRAGEN"
final_output_bucket = "gs://bioskryb-work-d8f6s9"
cromwell_runs_bucket = "gs://bioskryb-dev-cromwell-runs-8dhf5d"

    
output_base_location = "{}/{}/{}".format(final_output_bucket, project_name, "data/04-nosubsampling_n16_joint_genotyping/sentieon")
jj_sentieon_options_dict = {
        "read_from_cache": False,
        "default_runtime_attributes": {
                "zones": "us-central1-a us-central1-b us-central1-c us-central1-f",
                "noAddress": False
        },
        "final_workflow_outputs_dir": output_base_location,
        "use_relative_output_paths": True,
        "final_call_logs_dir": "{}/call_logs".format(output_base_location),
        "jes_gcs_root": cromwell_runs_bucket,
        "google_labels": {
                "pipeline-name": "sentieon-gvcftyper",
                "project-name": "comparing-gatk-sentieon-dragen"
        }
}

# %%
vcf_df = pd.DataFrame([gvcf_sentieon_filenames_n16], columns= [re.sub("_hc.g.vcf.gz", "_vcf=input", os.path.basename(_filename)) for _filename in gvcf_sentieon_filenames_n16])

gvcf_sentieon_index_filenames_n16 = ["{}.tbi".format(_filename) for  _filename in gvcf_sentieon_filenames_n16]
vcf_index_df = pd.DataFrame([gvcf_sentieon_index_filenames_n16], columns= [re.sub("_hc.g.vcf.gz.tbi", "_vcf_index=input", os.path.basename(_filename)) for _filename in gvcf_sentieon_index_filenames_n16])

ref_sequence = "gs://bioskryb-dev-resources-4j2g6d/Homo_sapiens_assembly38.fasta"
ref_sequence_index = "gs://bioskryb-dev-resources-4j2g6d/Homo_sapiens_assembly38.fasta.fai"
dbsnp_filename = "gs://bioskryb-dev-resources-4j2g6d/Homo_sapiens_assembly38.dbsnp138.vcf.gz"
dbsnp_filename_index = "gs://bioskryb-dev-resources-4j2g6d/Homo_sapiens_assembly38.dbsnp138.vcf.gz.tbi"
other_input_files_df = pd.DataFrame([[ref_sequence, ref_sequence_index, dbsnp_filename, dbsnp_filename_index]], columns=["ref=input", "ref_index=input", "dbsnp=input", "dbsnp_index=input"])
outputs_df = pd.DataFrame([["nosubsampling_n16_sentieon_joint_genotyping_sentieon.vcf.gz", "nosubsampling_n16_sentieon_joint_genotyping_sentieon.vcf.gz.tbi"]], columns = ["out_vcf=output", "out_vcf_index=output"])

inputs_df = pd.concat([vcf_df, vcf_index_df, other_input_files_df, outputs_df], axis = 1)

variant_subcommand = "{" + "} -v {".join(_colname.split("=")[0] for _colname in  vcf_df.columns) + "}"
gvcftyper_command_template = "sentieon driver -r {ref} -t 32  --algo GVCFtyper -v " + variant_subcommand + " -d {dbsnp} {out_vcf}"
gvcftyper_command_template

# %%
vcf_df

# %%
options_dict = {
        "default_runtime_attributes": {
                "zones": "us-central1-a us-central1-b us-central1-c us-central1-f",
                "noAddress": False,
                "bootDiskSizeGb": 20
        },
}

inputs_dict = requests.get("https://raw.githubusercontent.com/gatk-workflows/generic-wdl-script/master/generic-workflow.input.json").json()
inputs_dict["genericworkflow.docker_override"] = "gcr.io/bioskryb/sentieon-201911:latest"
inputs_dict["genericworkflow.GenericTask.machine_mem_gb"] = 32
inputs_dict["genericworkflow.GenericTask.disk_space_gb"] = 200
inputs_dict["genericworkflow.GenericTask.cpu"] = 32

gctyper_dcr = defaultCromwellRunner(auth_obj, gvcftyper_command_template, inputs_df, jj_sentieon_options_dict, inputs_dict, wdl_text= requests.get("https://raw.githubusercontent.com/gatk-workflows/generic-wdl-script/master/generic-workflow.wdl").text)

# %%
gctyper_dcr.submit_jobs()

# %%
gctyper_dcr.get_status()

# %% [markdown]
# ### Sentieion - VarCal

# %% [markdown]
# We next run Sentieon's SNP variant recalibration

# %%
varcal_df = pd.DataFrame([
    ["gs://bioskryb-work-d8f6s9/ComparingGatkSentieonDRAGEN/data/04-nosubsampling_n16_joint_genotyping/sentieon/f7791408-5ccb-415d-94c0-72c1802d5104/call-GenericTask/glob-eb940d6b5fb9e12ecfa084f32facbc84/nosubsampling_n16_sentieon_joint_genotyping_sentieon.vcf.gz", 
     "gs://bioskryb-work-d8f6s9/ComparingGatkSentieonDRAGEN/data/04-nosubsampling_n16_joint_genotyping/sentieon/f7791408-5ccb-415d-94c0-72c1802d5104/call-GenericTask/glob-eb940d6b5fb9e12ecfa084f32facbc84/nosubsampling_n16_sentieon_joint_genotyping_sentieon.vcf.gz.tbi",
     "gs://bioskryb-dev-resources-4j2g6d/Homo_sapiens_assembly38.fasta",
     "gs://bioskryb-dev-resources-4j2g6d/Homo_sapiens_assembly38.fasta.fai",
     "gs://gcp-public-data--broad-references/hg38/v0/hapmap_3.3.hg38.vcf.gz",
     "gs://gcp-public-data--broad-references/hg38/v0/hapmap_3.3.hg38.vcf.gz.tbi",
     "gs://gcp-public-data--broad-references/hg38/v0/1000G_omni2.5.hg38.vcf.gz",
     "gs://gcp-public-data--broad-references/hg38/v0/1000G_omni2.5.hg38.vcf.gz.tbi",
     "gs://gcp-public-data--broad-references/hg38/v0/1000G_phase1.snps.high_confidence.hg38.vcf.gz",
     "gs://gcp-public-data--broad-references/hg38/v0/1000G_phase1.snps.high_confidence.hg38.vcf.gz.tbi",
     "gs://gcp-public-data--broad-references/hg38/v0/Homo_sapiens_assembly38.dbsnp138.vcf",
     "gs://gcp-public-data--broad-references/hg38/v0/Homo_sapiens_assembly38.dbsnp138.vcf.idx",
     "snp_tranches_out.txt",
     "nosubsampling_n16_sentieon_joint_genotyping_sentieon.snp.recal.vcf.gz"
    ]
], columns= ['vcf=input', 'vcf_index=input', 'ref=input', 'ref_index=input', "hapmap=input", "hapmap_index=input", "omni=input", "omni_index=input", "onekg=input", "onekg_index=input","dbsnp=input","dbsnp_index=input", "snp_tranches_out=output", "snp_recal_vcf=output"])

varcal_command_template = "sentieon driver -r {ref} -t 6  --algo VarCal --annotation QD --annotation MQRankSum --annotation ReadPosRankSum --annotation FS --annotation MQ --annotation SOR --annotation DP -v {vcf} --var_type SNP --tranches_file {snp_tranches_out} --resource {hapmap} --resource_param hapmap,known=false,training=true,truth=true,prior=15  --resource {omni} --resource_param omni,known=false,training=true,truth=true,prior=12 --resource {onekg} --resource_param onekg,known=false,training=true,truth=false,prior=10 --resource {dbsnp} --resource_param dbsnp,known=true,training=false,truth=false,prior=7 {snp_recal_vcf}"

# %%
project_name = "ComparingGatkSentieonDRAGEN"
final_output_bucket = "gs://bioskryb-work-d8f6s9"
cromwell_runs_bucket = "gs://bioskryb-dev-cromwell-runs-8dhf5d"

    
output_base_location = "{}/{}/{}".format(final_output_bucket, project_name, "data/04-nosubsampling_n16_joint_genotyping/sentieon/varcal")
jj_varcal_sentieon_options_dict = {
        "read_from_cache": False,
        "default_runtime_attributes": {
                "zones": "us-central1-a us-central1-b us-central1-c us-central1-f",
                "noAddress": False
        },
        "final_workflow_outputs_dir": output_base_location,
        "use_relative_output_paths": True,
        "final_call_logs_dir": "{}/call_logs".format(output_base_location),
        "jes_gcs_root": cromwell_runs_bucket,
        "google_labels": {
                "pipeline-name": "sentieon-gvcftyper",
                "project-name": "comparing-gatk-sentieon-dragen"
        }
}

# %%
inputs_dict = requests.get("https://raw.githubusercontent.com/gatk-workflows/generic-wdl-script/master/generic-workflow.input.json").json()
inputs_dict["genericworkflow.docker_override"] = "gcr.io/bioskryb/sentieon-201911:latest"
inputs_dict["genericworkflow.GenericTask.machine_mem_gb"] = 6
inputs_dict["genericworkflow.GenericTask.disk_space_gb"] = 150
inputs_dict["genericworkflow.GenericTask.cpu"] = 6

snp_varcal_dcr = defaultCromwellRunner(auth_obj, varcal_command_template, varcal_df, jj_varcal_sentieon_options_dict, inputs_dict, wdl_text= requests.get("https://raw.githubusercontent.com/gatk-workflows/generic-wdl-script/master/generic-workflow.wdl").text)

# %%
snp_varcal_dcr.submit_jobs()

# %%
snp_varcal_dcr.get_status()

# %% [markdown]
# We next run Sentieon's indel variant recalibration

# %%
indel_varcal_df = pd.DataFrame([
    ["gs://bioskryb-work-d8f6s9/ComparingGatkSentieonDRAGEN/data/04-nosubsampling_n16_joint_genotyping/sentieon/f7791408-5ccb-415d-94c0-72c1802d5104/call-GenericTask/glob-eb940d6b5fb9e12ecfa084f32facbc84/nosubsampling_n16_sentieon_joint_genotyping_sentieon.vcf.gz", 
     "gs://bioskryb-work-d8f6s9/ComparingGatkSentieonDRAGEN/data/04-nosubsampling_n16_joint_genotyping/sentieon/f7791408-5ccb-415d-94c0-72c1802d5104/call-GenericTask/glob-eb940d6b5fb9e12ecfa084f32facbc84/nosubsampling_n16_sentieon_joint_genotyping_sentieon.vcf.gz.tbi",
     "gs://bioskryb-dev-resources-4j2g6d/Homo_sapiens_assembly38.fasta",
     "gs://bioskryb-dev-resources-4j2g6d/Homo_sapiens_assembly38.fasta.fai",
     "gs://gcp-public-data--broad-references/hg38/v0/Axiom_Exome_Plus.genotypes.all_populations.poly.hg38.vcf.gz", 
     "gs://gcp-public-data--broad-references/hg38/v0/Axiom_Exome_Plus.genotypes.all_populations.poly.hg38.vcf.gz.tbi", 
     "gs://gcp-public-data--broad-references/hg38/v0/Mills_and_1000G_gold_standard.indels.hg38.vcf.gz",
     "gs://gcp-public-data--broad-references/hg38/v0/Mills_and_1000G_gold_standard.indels.hg38.vcf.gz.tbi",
     "gs://gcp-public-data--broad-references/hg38/v0/Homo_sapiens_assembly38.dbsnp138.vcf",
     "gs://gcp-public-data--broad-references/hg38/v0/Homo_sapiens_assembly38.dbsnp138.vcf.idx",
     "indel_tranches_out.txt",
     "nosubsampling_n16_sentieon_joint_genotyping_sentieon.indel.recal.vcf.gz"
    ]
], columns= ['vcf=input', 'vcf_index=input', 'ref=input', 'ref_index=input', "axiom=input", "axiom_index=input", "mills=input", "mills_index=input", "dbsnp=input","dbsnp_index=input", "indel_tranches_out=output", "indel_recal_vcf=output"])

indel_varcal_command_template = "sentieon driver  -r {ref} -t 6  --algo VarCal --annotation FS --annotation ReadPosRankSum --annotation MQRankSum --annotation QD --annotation SOR --annotation DP -v {vcf} --var_type INDEL --tranches_file {indel_tranches_out} --resource {mills} --resource_param  mills,known=false,training=true,truth=true,prior=12 --resource {axiom} --resource_param axiom,known=false,training=true,truth=false,prior=10 --resource {dbsnp} --resource_param dbsnp,known=true,training=false,truth=false,prior=2 {indel_recal_vcf}"
indel_varcal_command_template

# %%
project_name = "ComparingGatkSentieonDRAGEN"
final_output_bucket = "gs://bioskryb-work-d8f6s9"
cromwell_runs_bucket = "gs://bioskryb-dev-cromwell-runs-8dhf5d"

    
output_base_location = "{}/{}/{}".format(final_output_bucket, project_name, "data/04-nosubsampling_n16_joint_genotyping/sentieon/varcal")
jj_varcal_sentieon_options_dict = {
        "read_from_cache": False,
        "default_runtime_attributes": {
                "zones": "us-central1-a us-central1-b us-central1-c us-central1-f",
                "noAddress": False
        },
        "final_workflow_outputs_dir": output_base_location,
        "use_relative_output_paths": True,
        "final_call_logs_dir": "{}/call_logs".format(output_base_location),
        "jes_gcs_root": cromwell_runs_bucket,
        "google_labels": {
                "pipeline-name": "sentieon-gvcftyper",
                "project-name": "comparing-gatk-sentieon-dragen"
        }
}

# %%
inputs_dict = requests.get("https://raw.githubusercontent.com/gatk-workflows/generic-wdl-script/master/generic-workflow.input.json").json()
inputs_dict["genericworkflow.docker_override"] = "gcr.io/bioskryb/sentieon-201911:latest"
inputs_dict["genericworkflow.GenericTask.machine_mem_gb"] = 6
inputs_dict["genericworkflow.GenericTask.disk_space_gb"] = 150
inputs_dict["genericworkflow.GenericTask.cpu"] = 6

indel_varcal_dcr = defaultCromwellRunner(auth_obj, indel_varcal_command_template, indel_varcal_df, jj_varcal_sentieon_options_dict, inputs_dict, wdl_text= requests.get("https://raw.githubusercontent.com/gatk-workflows/generic-wdl-script/master/generic-workflow.wdl").text)

# %%
indel_varcal_dcr.submit_jobs()

# %%
indel_varcal_dcr.get_status()

# %% [markdown]
# ### Sentieon - ApplyVarCal

# %%
apply_varcal_df = pd.DataFrame([
    ["gs://bioskryb-work-d8f6s9/ComparingGatkSentieonDRAGEN/data/04-nosubsampling_n16_joint_genotyping/sentieon/f7791408-5ccb-415d-94c0-72c1802d5104/call-GenericTask/glob-eb940d6b5fb9e12ecfa084f32facbc84/nosubsampling_n16_sentieon_joint_genotyping_sentieon.vcf.gz", 
     "gs://bioskryb-work-d8f6s9/ComparingGatkSentieonDRAGEN/data/04-nosubsampling_n16_joint_genotyping/sentieon/f7791408-5ccb-415d-94c0-72c1802d5104/call-GenericTask/glob-eb940d6b5fb9e12ecfa084f32facbc84/nosubsampling_n16_sentieon_joint_genotyping_sentieon.vcf.gz.tbi",
     "gs://bioskryb-dev-resources-4j2g6d/Homo_sapiens_assembly38.fasta",
     "gs://bioskryb-dev-resources-4j2g6d/Homo_sapiens_assembly38.fasta.fai",
     "gs://bioskryb-work-d8f6s9/ComparingGatkSentieonDRAGEN/data/04-nosubsampling_n16_joint_genotyping/sentieon/varcal/7af01187-7275-45a7-ab26-9b923fc8d714/call-GenericTask/glob-eb940d6b5fb9e12ecfa084f32facbc84/indel_tranches_out.txt",
     "gs://bioskryb-work-d8f6s9/ComparingGatkSentieonDRAGEN/data/04-nosubsampling_n16_joint_genotyping/sentieon/varcal/7af01187-7275-45a7-ab26-9b923fc8d714/call-GenericTask/glob-eb940d6b5fb9e12ecfa084f32facbc84/nosubsampling_n16_sentieon_joint_genotyping_sentieon.indel.recal.vcf.gz",
     "gs://bioskryb-work-d8f6s9/ComparingGatkSentieonDRAGEN/data/04-nosubsampling_n16_joint_genotyping/sentieon/varcal/7af01187-7275-45a7-ab26-9b923fc8d714/call-GenericTask/glob-eb940d6b5fb9e12ecfa084f32facbc84/nosubsampling_n16_sentieon_joint_genotyping_sentieon.indel.recal.vcf.gz.tbi",
     "gs://bioskryb-work-d8f6s9/ComparingGatkSentieonDRAGEN/data/04-nosubsampling_n16_joint_genotyping/sentieon/varcal/e8702941-94ce-430e-98b6-6cb5e1d2b25d/call-GenericTask/glob-eb940d6b5fb9e12ecfa084f32facbc84/snp_tranches_out.txt",
     "gs://bioskryb-work-d8f6s9/ComparingGatkSentieonDRAGEN/data/04-nosubsampling_n16_joint_genotyping/sentieon/varcal/e8702941-94ce-430e-98b6-6cb5e1d2b25d/call-GenericTask/glob-eb940d6b5fb9e12ecfa084f32facbc84/nosubsampling_n16_sentieon_joint_genotyping_sentieon.snp.recal.vcf.gz",
     "gs://bioskryb-work-d8f6s9/ComparingGatkSentieonDRAGEN/data/04-nosubsampling_n16_joint_genotyping/sentieon/varcal/e8702941-94ce-430e-98b6-6cb5e1d2b25d/call-GenericTask/glob-eb940d6b5fb9e12ecfa084f32facbc84/nosubsampling_n16_sentieon_joint_genotyping_sentieon.snp.recal.vcf.gz.tbi",
     "nosubsampling_n16_sentieon_joint_genotyping_sentieon.indel.varcal.final.vcf.gz",
     "nosubsampling_n16_sentieon_joint_genotyping_sentieon.indel.varcal.final.vcf.gz.tbi"
    ]
], columns= ['vcf=input', 'vcf_index=input', 'ref=input', 'ref_index=input', "indel_tranches=input", "indel_recal_vcf=input", "indel_recal_index_vcf=input", "snp_tranches=input", "snp_recal_vcf=input", "snp_recal_index_vcf=input", "final_varcal_vcf=output", "final_varcal_vcf_index=output"])

apply_varcal_command_template = "sentieon driver  -r {ref} -t 6  --algo ApplyVarCal --vqsr_model var_type=SNP,recal={snp_recal_vcf},tranches_file={snp_tranches},sensitivity=99.7 --vqsr_model var_type=INDEL,recal={indel_recal_vcf},tranches_file={indel_tranches},sensitivity=99.0 --vcf {vcf} {final_varcal_vcf}"
apply_varcal_command_template

# %%
project_name = "ComparingGatkSentieonDRAGEN"
final_output_bucket = "gs://bioskryb-work-d8f6s9"
cromwell_runs_bucket = "gs://bioskryb-dev-cromwell-runs-8dhf5d"

    
output_base_location = "{}/{}/{}".format(final_output_bucket, project_name, "data/04-nosubsampling_n16_joint_genotyping/sentieon/applyvarcal")
jj_applyvarcal_sentieon_options_dict = {
        "read_from_cache": False,
        "default_runtime_attributes": {
                "zones": "us-central1-a us-central1-b us-central1-c us-central1-f",
                "noAddress": False
        },
        "final_workflow_outputs_dir": output_base_location,
        "use_relative_output_paths": True,
        "final_call_logs_dir": "{}/call_logs".format(output_base_location),
        "jes_gcs_root": cromwell_runs_bucket,
        "google_labels": {
                "pipeline-name": "sentieon-gvcftyper",
                "project-name": "comparing-gatk-sentieon-dragen"
        }
}

# %%
inputs_dict = requests.get("https://raw.githubusercontent.com/gatk-workflows/generic-wdl-script/master/generic-workflow.input.json").json()
inputs_dict["genericworkflow.docker_override"] = "gcr.io/bioskryb/sentieon-201911:latest"
inputs_dict["genericworkflow.GenericTask.machine_mem_gb"] = 6
inputs_dict["genericworkflow.GenericTask.disk_space_gb"] = 150
inputs_dict["genericworkflow.GenericTask.cpu"] = 6

apply_varcal_dcr = defaultCromwellRunner(auth_obj, apply_varcal_command_template, apply_varcal_df, jj_applyvarcal_sentieon_options_dict, inputs_dict, wdl_text= requests.get("https://raw.githubusercontent.com/gatk-workflows/generic-wdl-script/master/generic-workflow.wdl").text)

# %%
apply_varcal_dcr.submit_jobs()

# %%
apply_varcal_dcr.get_status()

# %% [markdown]
# ## Measuring precision and sensitivity

# %% [markdown]
# The following was performed to acquire the vcf files for Sentieon and gatk samples:

# %% [markdown]
# `rcarter@bioskryb-dt:scratch$ gsutil cp gs://bioskryb-work-d8f6s9/ComparingGatkSentieonDRAGEN/data/04-nosubsampling_n16_joint_genotyping/sentieon/applyvarcal/95f90949-445b-4493-b80e-ddaf09353cda/call-GenericTask/**.vcf.gz* .`
#
# `rcarter@bioskryb-dt:scratch$ gsutil cp gs://bioskryb-work-d8f6s9/ComparingGatkSentieonDRAGEN/data/04-nosubsampling_n16_joint_genotyping/JointGenotyping/e00ab3ad-4e37-4676-af07-8a274f08c741/call-FinalGatherVcf/attempt-2/**.vcf.gz* .`
#
# `rcarter@bioskryb-dt:scratch$ cp  ~/BaseSpace/Projects/.id.161953803/AppSessions/.id.231671923/AppResults.239697619.joint/Files/dragen-joint.hard-filtered.vcf.gz* .`

# %% [markdown]
# GATK 4.1.3.0 (in Docker container) was used to isolate the SNP variants from each of the three platforms

# %% [markdown]
# `for i in *.vcf.gz; do PREFIX=$(echo $i | sed 's/.vcf.gz//'); gatk SelectVariants --select-type SNP  -V ${PREFIX}.vcf.gz -O ${PREFIX}.snps_only.vcf.gz; done`

# %% [markdown]
# The vcfs were split into indels and SNP vcfs, but were not filtered. Note that the Sentieon VCF was incorrenctly named, so it was renamed first to remove the '.indel' substring.

# %% [markdown]
# `for i in nosubsampling_n16_sentieon_joint_genotyping_sentieon.indel.*; do NEW_NAME=$(echo $i | sed 's/.indel//'); mv $i $NEW_NAME; done`

# %%
# %%writefile tracked_data/run_rtg.sh
# # baseline vcf
# # baseline sample_name
# # comparison vcf
# # joined comparison vcfs
# #filder suffix
# # extra options
# #!/usr/bin/env bash
# echo $4 | sed 's/,/\n/g' | parallel --max-args=1 --jobs 8 /home/rcarter/rtg-tools/bin/rtg-tools-3.10.1-4d58eadb/rtg RTG_MEM=6G vcfeval -b $1 -c $3 --sample=${2},{} -o scratch/${2}_vs_{}-${5} -e /home/rcarter/Homo_sapiens_assembly38_n25chr.bed -t /home/rcarter/R_bioskryb_na12878_analysis/NA12878_comparison/SDF/  --squash-ploidy $6
# Out:
# Overwriting tracked_data/run_rtg.sh

# %%
# !chmod 755 tracked_data/run_rtg.sh

# %% [markdown]
# all non-bulk samples are compared against bulk  for each of the three genotyping platforms

# %% [markdown]
# #### GATK

# %%
gatk_snps_vcf = vcf.Reader(open('scratch/nosubsampling_n16_gatk_joint_genotyping_gatk.snps_only.vcf.gz', 'rb'))
gatk_samplenames = gatk_snps_vcf.samples
gatk_samplenames
# Out:
# ['4249-JW-10',
#  '4249-JW-14',
#  '4249-JW-16',
#  '4249-JW-17',
#  '4249-JW-18',
#  '4249-JW-19',
#  '4249-JW-23',
#  '4249-JW-25',
#  '4249-JW-27',
#  '4249-JW-30',
#  '4249-JW-32',
#  '4249-JW-36',
#  '4249-JW-38',
#  '4249-JW-40',
#  '4249-JW-42',
#  '4249-JW-43',
#  'NA12878_Bulk2']

# %%
gatk_joined_samplenames = ",".join(gatk_samplenames)
# !tracked_data/run_rtg.sh scratch/nosubsampling_n16_gatk_joint_genotyping_gatk.snps_only.vcf.gz NA12878_Bulk2 scratch/nosubsampling_n16_gatk_joint_genotyping_gatk.snps_only.vcf.gz $gatk_joined_samplenames  n16_gatk "--vcf-score-field=INFO.AS_VQSLOD"
# Out:
# Threshold  True-pos-baseline  True-pos-call  False-pos  False-neg  Precision  Sensitivity  F-measure
# ----------------------------------------------------------------------------------------------------
#    -4.324            3213852        3213852     142639     335394     0.9575       0.9055     0.9308
#      None            3220138        3220138     144497     329108     0.9571       0.9073     0.9315
#
# There were 8133 variants not thresholded in ROC data files due to missing or invalid AS_VQSLOD (INFO) values.
# Threshold  True-pos-baseline  True-pos-call  False-pos  False-neg  Precision  Sensitivity  F-measure
# ----------------------------------------------------------------------------------------------------
#    -4.324            3303278        3303278     148482     245968     0.9570       0.9307     0.9437
#      None            3310365        3310365     151675     238881     0.9562       0.9327     0.9443
#
# There were 10270 variants not thresholded in ROC data files due to missing or invalid AS_VQSLOD (INFO) values.
# Threshold  True-pos-baseline  True-pos-call  False-pos  False-neg  Precision  Sensitivity  F-measure
# ----------------------------------------------------------------------------------------------------
#    -4.346            3280976        3280976     145288     268270     0.9576       0.9244     0.9407
#      None            3287886        3287886     148187     261360     0.9569       0.9264     0.9414
#
# There were 9798 variants not thresholded in ROC data files due to missing or invalid AS_VQSLOD (INFO) values.
# Threshold  True-pos-baseline  True-pos-call  False-pos  False-neg  Precision  Sensitivity  F-measure
# ----------------------------------------------------------------------------------------------------
#    -4.261            3293147        3293147     145721     256099     0.9576       0.9278     0.9425
#      None            3300367        3300367     148381     248879     0.9570       0.9299     0.9432
#
# There were 9860 variants not thresholded in ROC data files due to missing or invalid AS_VQSLOD (INFO) values.
# Threshold  True-pos-baseline  True-pos-call  False-pos  False-neg  Precision  Sensitivity  F-measure
# ----------------------------------------------------------------------------------------------------
#    -4.261            3137422        3137422     140275     411824     0.9572       0.8840     0.9191
#      None            3144169        3144169     143070     405077     0.9565       0.8859     0.9198
#
# There were 9522 variants not thresholded in ROC data files due to missing or invalid AS_VQSLOD (INFO) values.
# Threshold  True-pos-baseline  True-pos-call  False-pos  False-neg  Precision  Sensitivity  F-measure
# ----------------------------------------------------------------------------------------------------
#    -4.324            3187806        3187806     143789     361440     0.9568       0.8982     0.9266
#      None            3194543        3194543     146724     354703     0.9561       0.9001     0.9272
#
# There were 9662 variants not thresholded in ROC data files due to missing or invalid AS_VQSLOD (INFO) values.
# Threshold  True-pos-baseline  True-pos-call  False-pos  False-neg  Precision  Sensitivity  F-measure
# ----------------------------------------------------------------------------------------------------
#    -4.336            3331580        3331580     144317     217666     0.9585       0.9387     0.9485
#      None            3338924        3338924     147435     210322     0.9577       0.9407     0.9492
#
# There were 10454 variants not thresholded in ROC data files due to missing or invalid AS_VQSLOD (INFO) values.
# Threshold  True-pos-baseline  True-pos-call  False-pos  False-neg  Precision  Sensitivity  F-measure
# ----------------------------------------------------------------------------------------------------
#    -4.324            2965393        2965393     134750     583853     0.9565       0.8355     0.8919
#      None            2971984        2971984     137812     577262     0.9557       0.8374     0.8926
#
# There were 9638 variants not thresholded in ROC data files due to missing or invalid AS_VQSLOD (INFO) values.
# Threshold  True-pos-baseline  True-pos-call  False-pos  False-neg  Precision  Sensitivity  F-measure
# ----------------------------------------------------------------------------------------------------
#    -4.346            3227307        3227307     139094     321939     0.9587       0.9093     0.9333
#      None            3234343        3234343     142152     314903     0.9579       0.9113     0.9340
#
# There were 10088 variants not thresholded in ROC data files due to missing or invalid AS_VQSLOD (INFO) values.
# Threshold  True-pos-baseline  True-pos-call  False-pos  False-neg  Precision  Sensitivity  F-measure
# ----------------------------------------------------------------------------------------------------
#    -4.346            3223248        3223248     142771     325998     0.9576       0.9082     0.9322
#      None            3230325        3230325     145990     318921     0.9568       0.9101     0.9329
#
# There were 10286 variants not thresholded in ROC data files due to missing or invalid AS_VQSLOD (INFO) values.
# Threshold  True-pos-baseline  True-pos-call  False-pos  False-neg  Precision  Sensitivity  F-measure
# ----------------------------------------------------------------------------------------------------
#    -4.346            3081392        3081392     137673     467854     0.9572       0.8682     0.9105
#      None            3088203        3088203     140696     461043     0.9564       0.8701     0.9112
#
# There were 9822 variants not thresholded in ROC data files due to missing or invalid AS_VQSLOD (INFO) values.
# Threshold  True-pos-baseline  True-pos-call  False-pos  False-neg  Precision  Sensitivity  F-measure
# ----------------------------------------------------------------------------------------------------
#    -4.346            3067269        3067269     134858     481977     0.9579       0.8642     0.9086
#      None            3074302        3074302     138037     474944     0.9570       0.8662     0.9093
#
# There were 10200 variants not thresholded in ROC data files due to missing or invalid AS_VQSLOD (INFO) values.
# Threshold  True-pos-baseline  True-pos-call  False-pos  False-neg  Precision  Sensitivity  F-measure
# ----------------------------------------------------------------------------------------------------
#    -4.324            3038415        3038415     135384     510831     0.9573       0.8561     0.9039
#      None            3045316        3045316     138418     503930     0.9565       0.8580     0.9046
#
# There were 9921 variants not thresholded in ROC data files due to missing or invalid AS_VQSLOD (INFO) values.
# Threshold  True-pos-baseline  True-pos-call  False-pos  False-neg  Precision  Sensitivity  F-measure
# ----------------------------------------------------------------------------------------------------
#    -4.324            2517592        2517592     120820    1031654     0.9542       0.7093     0.8137
#      None            2523219        2523219     123575    1026027     0.9533       0.7109     0.8145
#
# There were 8370 variants not thresholded in ROC data files due to missing or invalid AS_VQSLOD (INFO) values.
# Threshold  True-pos-baseline  True-pos-call  False-pos  False-neg  Precision  Sensitivity  F-measure
# ----------------------------------------------------------------------------------------------------
#    -4.346            3221916        3221916     142254     327330     0.9577       0.9078     0.9321
#      None            3228934        3228934     145335     320312     0.9569       0.9098     0.9327
#
# There were 10092 variants not thresholded in ROC data files due to missing or invalid AS_VQSLOD (INFO) values.
# Threshold  True-pos-baseline  True-pos-call  False-pos  False-neg  Precision  Sensitivity  F-measure
# ----------------------------------------------------------------------------------------------------
#    -4.346            3120195        3120195     139419     429051     0.9572       0.8791     0.9165
#      None            3126855        3126855     142455     422391     0.9564       0.8810     0.9172
#
# There were 9683 variants not thresholded in ROC data files due to missing or invalid AS_VQSLOD (INFO) values.
# Threshold  True-pos-baseline  True-pos-call  False-pos  False-neg  Precision  Sensitivity  F-measure
# ----------------------------------------------------------------------------------------------------
#    -5.075            3537495        3537495          0      11751     1.0000       0.9967     0.9983
#      None            3549246        3549246          0          0     1.0000       1.0000     1.0000
#
# There were 11751 variants not thresholded in ROC data files due to missing or invalid AS_VQSLOD (INFO) values.

# %%
# !tracked_data/run_rtg.sh scratch/nosubsampling_n16_gatk_joint_genotyping_gatk.snps_only.vcf.gz NA12878_Bulk2 scratch/nosubsampling_n16_gatk_joint_genotyping_gatk.snps_only.vcf.gz 4249-JW-10,4249-JW-27 all_variants_n16_gatk "--vcf-score-field=INFO.AS_VQSLOD --all-records"
# Out:
# Threshold  True-pos-baseline  True-pos-call  False-pos  False-neg  Precision  Sensitivity  F-measure
# ----------------------------------------------------------------------------------------------------
#   -14.260            3310479        3310479     196923     466513     0.9439       0.8765     0.9089
#      None            3339950        3339950     234330     437042     0.9344       0.8843     0.9087
#
# There were 8753 variants not thresholded in ROC data files due to missing or invalid AS_VQSLOD (INFO) values.
# Threshold  True-pos-baseline  True-pos-call  False-pos  False-neg  Precision  Sensitivity  F-measure
# ----------------------------------------------------------------------------------------------------
#   -15.706            3177830        3177830     191953     599162     0.9430       0.8414     0.8893
#      None            3203976        3203976     224954     573016     0.9344       0.8483     0.8893
#
# There were 10786 variants not thresholded in ROC data files due to missing or invalid AS_VQSLOD (INFO) values.

# %% [markdown]
# #### Sentieon

# %%
sentieon_snps_vcf = vcf.Reader(open('scratch/nosubsampling_n16_sentieon_joint_genotyping_sentieon.varcal.final.snps_only.vcf.gz', 'rb'))
sentieon_samplenames = [_sample_name for _sample_name in sentieon_snps_vcf.samples]
sentieon_samplenames
# Out:
# ['4249-JW-10',
#  '4249-JW-14',
#  '4249-JW-16',
#  '4249-JW-17',
#  '4249-JW-18',
#  '4249-JW-19',
#  '4249-JW-23',
#  '4249-JW-25',
#  '4249-JW-27',
#  '4249-JW-30',
#  '4249-JW-32',
#  '4249-JW-36',
#  '4249-JW-38',
#  '4249-JW-40',
#  '4249-JW-42',
#  '4249-JW-43',
#  'NA12878_Bulk2']

# %%
sentieon_joined_samplenames = ",".join(sentieon_samplenames)
# !tracked_data/run_rtg.sh scratch/nosubsampling_n16_sentieon_joint_genotyping_sentieon.varcal.final.snps_only.vcf.gz NA12878_Bulk2 scratch/nosubsampling_n16_sentieon_joint_genotyping_sentieon.varcal.final.snps_only.vcf.gz $sentieon_joined_samplenames n16_sentieon "--vcf-score-field=INFO.VQSLOD"
# Out:
# Threshold  True-pos-baseline  True-pos-call  False-pos  False-neg  Precision  Sensitivity  F-measure
# ----------------------------------------------------------------------------------------------------
#    -8.433            3720757        3720757          0          0     1.0000       1.0000     1.0000
#      None            3720757        3720757          0          0     1.0000       1.0000     1.0000

# %%
# !tracked_data/run_rtg.sh scratch/nosubsampling_n16_sentieon_joint_genotyping_sentieon.varcal.final.snps_only.vcf.gz NA12878_Bulk2 scratch/nosubsampling_n16_sentieon_joint_genotyping_sentieon.varcal.final.snps_only.vcf.gz 4249-JW-10,4249-JW-27 all_variants_n16_sentieon "--vcf-score-field=INFO.VQSLOD --all-records"
# Out:
#  Threshold  True-pos-baseline  True-pos-call  False-pos  False-neg  Precision  Sensitivity  F-measure
# -----------------------------------------------------------------------------------------------------
# -61878.423            3274253        3274253     145739     554828     0.9574       0.8551     0.9034
#       None            3274254        3274254     145741     554827     0.9574       0.8551     0.9034
#
#  Threshold  True-pos-baseline  True-pos-call  False-pos  False-neg  Precision  Sensitivity  F-measure
# -----------------------------------------------------------------------------------------------------
# -73629.829            3410571        3410571     151850     418510     0.9574       0.8907     0.9228
#       None            3410571        3410571     151850     418510     0.9574       0.8907     0.9228

# %% [markdown]
# #### DRAGEN

# %%
dragen_snps_vcf = vcf.Reader(open('scratch/dragen-joint.hard-filtered.snps_only.vcf.gz', 'rb'))
dragen_samplenames = dragen_snps_vcf.samples
#dragen_samplenames = [_sample_name for _sample_name in dragen_snps_vcf.samples if _sample_name != 'NA12878-Bulk2-merged-n450x10e6']
dragen_samplenames
# Out:
# ['4249-JW-10_combined',
#  '4249-JW-14_combined',
#  '4249-JW-16_combined',
#  '4249-JW-17_combined',
#  '4249-JW-18_combined',
#  '4249-JW-19_combined',
#  '4249-JW-23_combined',
#  '4249-JW-25_combined',
#  '4249-JW-27_combined',
#  '4249-JW-30_combined',
#  '4249-JW-32_combined',
#  '4249-JW-36_combined',
#  '4249-JW-38_combined',
#  '4249-JW-40_combined',
#  '4249-JW-42_combined',
#  '4249-JW-43_combined',
#  'NA12878-Bulk2-merged-n450x10e6']

# %%
dragen_joined_samplenames = ",".join(dragen_samplenames)
# !tracked_data/run_rtg.sh scratch/dragen-joint.hard-filtered.snps_only.vcf.gz NA12878-Bulk2-merged-n450x10e6 scratch/dragen-joint.hard-filtered.snps_only.vcf.gz $dragen_joined_samplenames n16_dragen  "--vcf-score-field=GQ"
# Out:
# Threshold  True-pos-baseline  True-pos-call  False-pos  False-neg  Precision  Sensitivity  F-measure
# ----------------------------------------------------------------------------------------------------
#     2.000            3575453        3575453     290864     371361     0.9248       0.9059     0.9152
#      None            3575468        3575468     291474     371346     0.9246       0.9059     0.9152
#
# There were 591 variants not thresholded in ROC data files due to missing or invalid GQ (FORMAT) values.
# Threshold  True-pos-baseline  True-pos-call  False-pos  False-neg  Precision  Sensitivity  F-measure
# ----------------------------------------------------------------------------------------------------
#     2.000            3634659        3634659     316158     312155     0.9200       0.9209     0.9204
#      None            3634672        3634672     316670     312142     0.9199       0.9209     0.9204
#
# There were 494 variants not thresholded in ROC data files due to missing or invalid GQ (FORMAT) values.
# Threshold  True-pos-baseline  True-pos-call  False-pos  False-neg  Precision  Sensitivity  F-measure
# ----------------------------------------------------------------------------------------------------
#     2.000            3273458        3273458     294481     673356     0.9175       0.8294     0.8712
#      None            3273469        3273469     295046     673345     0.9173       0.8294     0.8711
#
# There were 549 variants not thresholded in ROC data files due to missing or invalid GQ (FORMAT) values.
# Threshold  True-pos-baseline  True-pos-call  False-pos  False-neg  Precision  Sensitivity  F-measure
# ----------------------------------------------------------------------------------------------------
#     1.000            3613773        3613773     291013     333041     0.9255       0.9156     0.9205
#      None            3613781        3613781     291511     333033     0.9254       0.9156     0.9205
#
# There were 506 variants not thresholded in ROC data files due to missing or invalid GQ (FORMAT) values.
# Threshold  True-pos-baseline  True-pos-call  False-pos  False-neg  Precision  Sensitivity  F-measure
# ----------------------------------------------------------------------------------------------------
#     2.000            3669511        3669511     300840     277303     0.9242       0.9297     0.9270
#      None            3669534        3669534     301458     277280     0.9241       0.9297     0.9269
#
# There were 611 variants not thresholded in ROC data files due to missing or invalid GQ (FORMAT) values.
# Threshold  True-pos-baseline  True-pos-call  False-pos  False-neg  Precision  Sensitivity  F-measure
# ----------------------------------------------------------------------------------------------------
#     2.000            3655618        3655618     332261     291196     0.9167       0.9262     0.9214
#      None            3655636        3655636     332760     291178     0.9166       0.9262     0.9214
#
# There were 490 variants not thresholded in ROC data files due to missing or invalid GQ (FORMAT) values.
# Threshold  True-pos-baseline  True-pos-call  False-pos  False-neg  Precision  Sensitivity  F-measure
# ----------------------------------------------------------------------------------------------------
#     1.000            3529715        3529715     285187     417099     0.9252       0.8943     0.9095
#      None            3529724        3529724     285662     417090     0.9251       0.8943     0.9095
#
# There were 484 variants not thresholded in ROC data files due to missing or invalid GQ (FORMAT) values.
# Threshold  True-pos-baseline  True-pos-call  False-pos  False-neg  Precision  Sensitivity  F-measure
# ----------------------------------------------------------------------------------------------------
#     2.000            3533845        3533845     304005     412969     0.9208       0.8954     0.9079
#      None            3533857        3533857     304496     412957     0.9207       0.8954     0.9078
#
# There were 480 variants not thresholded in ROC data files due to missing or invalid GQ (FORMAT) values.
# Threshold  True-pos-baseline  True-pos-call  False-pos  False-neg  Precision  Sensitivity  F-measure
# ----------------------------------------------------------------------------------------------------
#     2.000            3376201        3376201     305849     570613     0.9169       0.8554     0.8851
#      None            3376211        3376211     306280     570603     0.9168       0.8554     0.8851
#
# There were 419 variants not thresholded in ROC data files due to missing or invalid GQ (FORMAT) values.
# Threshold  True-pos-baseline  True-pos-call  False-pos  False-neg  Precision  Sensitivity  F-measure
# ----------------------------------------------------------------------------------------------------
#     2.000            3544791        3544791     316818     402023     0.9180       0.8981     0.9079
#      None            3544808        3544808     317258     402006     0.9179       0.8981     0.9079
#
# There were 430 variants not thresholded in ROC data files due to missing or invalid GQ (FORMAT) values.
# Threshold  True-pos-baseline  True-pos-call  False-pos  False-neg  Precision  Sensitivity  F-measure
# ----------------------------------------------------------------------------------------------------
#     1.000            3399462        3399462     318885     547352     0.9142       0.8613     0.8870
#      None            3399468        3399468     319408     547346     0.9141       0.8613     0.8869
#
# There were 529 variants not thresholded in ROC data files due to missing or invalid GQ (FORMAT) values.
# Threshold  True-pos-baseline  True-pos-call  False-pos  False-neg  Precision  Sensitivity  F-measure
# ----------------------------------------------------------------------------------------------------
#     2.000            2799309        2799309     296607    1147505     0.9042       0.7093     0.7949
#      None            2799321        2799321     297056    1147493     0.9041       0.7093     0.7949
#
# There were 431 variants not thresholded in ROC data files due to missing or invalid GQ (FORMAT) values.
# Threshold  True-pos-baseline  True-pos-call  False-pos  False-neg  Precision  Sensitivity  F-measure
# ----------------------------------------------------------------------------------------------------
#     2.000            3546984        3546984     332533     399830     0.9143       0.8987     0.9064
#      None            3547005        3547005     333009     399809     0.9142       0.8987     0.9064
#
# There were 463 variants not thresholded in ROC data files due to missing or invalid GQ (FORMAT) values.
# Threshold  True-pos-baseline  True-pos-call  False-pos  False-neg  Precision  Sensitivity  F-measure
# ----------------------------------------------------------------------------------------------------
#     2.000            3481051        3481051     297622     465763     0.9212       0.8820     0.9012
#      None            3481064        3481064     298239     465750     0.9211       0.8820     0.9011
#
# There were 602 variants not thresholded in ROC data files due to missing or invalid GQ (FORMAT) values.
# Threshold  True-pos-baseline  True-pos-call  False-pos  False-neg  Precision  Sensitivity  F-measure
# ----------------------------------------------------------------------------------------------------
#     2.000            3585443        3585443     285873     361371     0.9262       0.9084     0.9172
#      None            3585455        3585455     286442     361359     0.9260       0.9084     0.9171
#
# There were 558 variants not thresholded in ROC data files due to missing or invalid GQ (FORMAT) values.
# Threshold  True-pos-baseline  True-pos-call  False-pos  False-neg  Precision  Sensitivity  F-measure
# ----------------------------------------------------------------------------------------------------
#     2.000            3351968        3351968     311151     594846     0.9151       0.8493     0.8809
#      None            3351981        3351981     311565     594833     0.9150       0.8493     0.8809
#
# There were 398 variants not thresholded in ROC data files due to missing or invalid GQ (FORMAT) values.
# Threshold  True-pos-baseline  True-pos-call  False-pos  False-neg  Precision  Sensitivity  F-measure
# ----------------------------------------------------------------------------------------------------
#     1.000            3946790        3946790          0         24     1.0000       1.0000     1.0000
#      None            3946814        3946814          0          0     1.0000       1.0000     1.0000
#
# There were 24 variants not thresholded in ROC data files due to missing or invalid GQ (FORMAT) values.

# %%
# !tracked_data/run_rtg.sh scratch/dragen-joint.hard-filtered.snps_only.vcf.gz NA12878-Bulk2-merged-n450x10e6 scratch/dragen-joint.hard-filtered.snps_only.vcf.gz 4249-JW-10_combined,4249-JW-27_combined all_variants_n16_dragen  "--vcf-score-field=GQ  --all-records"
# Out:
# Threshold  True-pos-baseline  True-pos-call  False-pos  False-neg  Precision  Sensitivity  F-measure
# ----------------------------------------------------------------------------------------------------
#     1.000            3399638        3399638     491441     568635     0.8737       0.8567     0.8651
#      None            3399644        3399644     491964     568629     0.8736       0.8567     0.8651
#
# There were 529 variants not thresholded in ROC data files due to missing or invalid GQ (FORMAT) values.
# Threshold  True-pos-baseline  True-pos-call  False-pos  False-neg  Precision  Sensitivity  F-measure
# ----------------------------------------------------------------------------------------------------
#     3.000            3501461        3501461     428364     466812     0.8910       0.8824     0.8867
#      None            3534030        3534030     470214     434243     0.8826       0.8906     0.8866
#
# There were 480 variants not thresholded in ROC data files due to missing or invalid GQ (FORMAT) values.

# %% [markdown]
# ### Gather RTG summary files

# %%
summary_files = !find scratch/*_{dragen,sentieon,gatk} -name summary.txt | grep -v giab | grep -v all_variants
summary_files
# Out:
# ['scratch/NA12878-Bulk2-merged-n450x10e6_vs_4249-JW-10_combined-n16_dragen/summary.txt',
#  'scratch/NA12878-Bulk2-merged-n450x10e6_vs_4249-JW-14_combined-n16_dragen/summary.txt',
#  'scratch/NA12878-Bulk2-merged-n450x10e6_vs_4249-JW-16_combined-n16_dragen/summary.txt',
#  'scratch/NA12878-Bulk2-merged-n450x10e6_vs_4249-JW-17_combined-n16_dragen/summary.txt',
#  'scratch/NA12878-Bulk2-merged-n450x10e6_vs_4249-JW-18_combined-n16_dragen/summary.txt',
#  'scratch/NA12878-Bulk2-merged-n450x10e6_vs_4249-JW-19_combined-n16_dragen/summary.txt',
#  'scratch/NA12878-Bulk2-merged-n450x10e6_vs_4249-JW-23_combined-n16_dragen/summary.txt',
#  'scratch/NA12878-Bulk2-merged-n450x10e6_vs_4249-JW-25_combined-n16_dragen/summary.txt',
#  'scratch/NA12878-Bulk2-merged-n450x10e6_vs_4249-JW-27_combined-n16_dragen/summary.txt',
#  'scratch/NA12878-Bulk2-merged-n450x10e6_vs_4249-JW-30_combined-n16_dragen/summary.txt',
#  'scratch/NA12878-Bulk2-merged-n450x10e6_vs_4249-JW-32_combined-n16_dragen/summary.txt',
#  'scratch/NA12878-Bulk2-merged-n450x10e6_vs_4249-JW-36_combined-n16_dragen/summary.txt',
#  'scratch/NA12878-Bulk2-merged-n450x10e6_vs_4249-JW-38_combined-n16_dragen/summary.txt',
#  'scratch/NA12878-Bulk2-merged-n450x10e6_vs_4249-JW-40_combined-n16_dragen/summary.txt',
#  'scratch/NA12878-Bulk2-merged-n450x10e6_vs_4249-JW-42_combined-n16_dragen/summary.txt',
#  'scratch/NA12878-Bulk2-merged-n450x10e6_vs_4249-JW-43_combined-n16_dragen/summary.txt',
#  'scratch/NA12878-Bulk2-merged-n450x10e6_vs_NA12878-Bulk2-merged-n450x10e6-n16_dragen/summary.txt',
#  'scratch/NA12878_Bulk2_vs_4249-JW-10-n16_sentieon/summary.txt',
#  'scratch/NA12878_Bulk2_vs_4249-JW-14-n16_sentieon/summary.txt',
#  'scratch/NA12878_Bulk2_vs_4249-JW-16-n16_sentieon/summary.txt',
#  'scratch/NA12878_Bulk2_vs_4249-JW-17-n16_sentieon/summary.txt',
#  'scratch/NA12878_Bulk2_vs_4249-JW-18-n16_sentieon/summary.txt',
#  'scratch/NA12878_Bulk2_vs_4249-JW-19-n16_sentieon/summary.txt',
#  'scratch/NA12878_Bulk2_vs_4249-JW-23-n16_sentieon/summary.txt',
#  'scratch/NA12878_Bulk2_vs_4249-JW-25-n16_sentieon/summary.txt',
#  'scratch/NA12878_Bulk2_vs_4249-JW-27-n16_sentieon/summary.txt',
#  'scratch/NA12878_Bulk2_vs_4249-JW-30-n16_sentieon/summary.txt',
#  'scratch/NA12878_Bulk2_vs_4249-JW-32-n16_sentieon/summary.txt',
#  'scratch/NA12878_Bulk2_vs_4249-JW-36-n16_sentieon/summary.txt',
#  'scratch/NA12878_Bulk2_vs_4249-JW-38-n16_sentieon/summary.txt',
#  'scratch/NA12878_Bulk2_vs_4249-JW-40-n16_sentieon/summary.txt',
#  'scratch/NA12878_Bulk2_vs_4249-JW-42-n16_sentieon/summary.txt',
#  'scratch/NA12878_Bulk2_vs_4249-JW-43-n16_sentieon/summary.txt',
#  'scratch/NA12878_Bulk2_vs_NA12878_Bulk2-n16_sentieon/summary.txt',
#  'scratch/NA12878_Bulk2_vs_4249-JW-10-n16_gatk/summary.txt',
#  'scratch/NA12878_Bulk2_vs_4249-JW-14-n16_gatk/summary.txt',
#  'scratch/NA12878_Bulk2_vs_4249-JW-16-n16_gatk/summary.txt',
#  'scratch/NA12878_Bulk2_vs_4249-JW-17-n16_gatk/summary.txt',
#  'scratch/NA12878_Bulk2_vs_4249-JW-18-n16_gatk/summary.txt',
#  'scratch/NA12878_Bulk2_vs_4249-JW-19-n16_gatk/summary.txt',
#  'scratch/NA12878_Bulk2_vs_4249-JW-23-n16_gatk/summary.txt',
#  'scratch/NA12878_Bulk2_vs_4249-JW-25-n16_gatk/summary.txt',
#  'scratch/NA12878_Bulk2_vs_4249-JW-27-n16_gatk/summary.txt',
#  'scratch/NA12878_Bulk2_vs_4249-JW-30-n16_gatk/summary.txt',
#  'scratch/NA12878_Bulk2_vs_4249-JW-32-n16_gatk/summary.txt',
#  'scratch/NA12878_Bulk2_vs_4249-JW-36-n16_gatk/summary.txt',
#  'scratch/NA12878_Bulk2_vs_4249-JW-38-n16_gatk/summary.txt',
#  'scratch/NA12878_Bulk2_vs_4249-JW-40-n16_gatk/summary.txt',
#  'scratch/NA12878_Bulk2_vs_4249-JW-42-n16_gatk/summary.txt',
#  'scratch/NA12878_Bulk2_vs_4249-JW-43-n16_gatk/summary.txt',
#  'scratch/NA12878_Bulk2_vs_NA12878_Bulk2-n16_gatk/summary.txt']

# %%
df_list = []
for _summary_file in summary_files:
    comparison_dir_name = _summary_file.split("/")[1]
    sample_name = re.sub("^.+vs_(.+)-n16.*", "\\1", comparison_dir_name)
    sample_name = re.sub("_combined", "", sample_name)
    sample_name = re.sub("NA12878-Bulk2-merged-n450x10e6", "NA12878_Bulk2", sample_name)
    platform = re.sub("^.+-n16.", "", comparison_dir_name)
    temp_df = pd.read_csv(_summary_file, skiprows=2, sep = "[\t ]+", header = None, names=["Threshold","True-pos-baseline","True-pos-call","False-pos","False-neg","Precision","Sensitivity","F-measure"]).head(1)
    temp_df['sample_name'] = sample_name
    temp_df['platform'] = platform
    df_list.append(temp_df)
rtg_summary_df = pd.concat(df_list)
rtg_summary_df
# Out:
# /home/rcarter/anacon3/lib/python3.7/site-packages/ipykernel_launcher.py:8: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   Threshold  True-pos-baseline  True-pos-call  False-pos  False-neg
# 0     0.9142       0.8613     0.8870     4249-JW-27    dragen
# 0     0.9169       0.8554     0.8851     4249-JW-30    dragen
# 0     0.9151       0.8493     0.8809     4249-JW-32    dragen
# 0     0.9042       0.7093     0.7949     4249-JW-36    dragen
# 0     0.9180       0.8981     0.9079     4249-JW-38    dragen
# 0     0.9143       0.8987     0.9064     4249-JW-40    dragen
# 0     0.9262       0.9084     0.9172     4249-JW-42    dragen
# 0     0.9212       0.8820     0.9012     4249-JW-43    dragen
# 0     1.0000       1.0000     1.0000  NA12878_Bulk2    dragen
# 0     0.9685       0.9018     0.9339     4249-JW-10  sentieon
# 0     0.9696       0.9234     0.9459     4249-JW-14  sentieon
# 0     0.9677       0.8842     0.9241     4249-JW-16  sentieon
# 0     0.9686       0.8954     0.9305     4249-JW-17  sentieon
# 0     0.9687       0.9210     0.9443     4249-JW-18  sentieon
# 0     0.9683       0.9268     0.9471     4249-JW-19  sentieon
# 0     0.9669       0.8328     0.8948     4249-JW-23  sentieon
# 0     0.9694       0.9348     0.9518     4249-JW-25  sentieon
# 0     0.9682       0.8656     0.9140     4249-JW-27  sentieon
# 0     0.9687       0.8610     0.9117     4249-JW-30  sentieon
# 0     0.9679       0.8531     0.9069     4249-JW-32  sentieon
# 0     0.9639       0.7082     0.8165     4249-JW-36  sentieon
# 0     0.9700       0.9050     0.9363     4249-JW-38  sentieon
# 0     0.9686       0.9042     0.9353     4249-JW-40  sentieon
# 0     0.9687       0.9046     0.9356     4249-JW-42  sentieon
# 0     0.9679       0.8760     0.9196     4249-JW-43  sentieon
# 0     1.0000       1.0000     1.0000  NA12878_Bulk2  sentieon
# 0     0.9575       0.9055     0.9308     4249-JW-10      gatk
# 0     0.9576       0.9278     0.9425     4249-JW-14      gatk
# 0     0.9572       0.8840     0.9191     4249-JW-16      gatk
# 0     0.9568       0.8982     0.9266     4249-JW-17      gatk
# 0     0.9576       0.9244     0.9407     4249-JW-18      gatk
# 0     0.9570       0.9307     0.9437     4249-JW-19      gatk
# 0     0.9565       0.8355     0.8919     4249-JW-23      gatk
# 0     0.9585       0.9387     0.9485     4249-JW-25      gatk
# 0     0.9572       0.8682     0.9105     4249-JW-27      gatk
# 0     0.9579       0.8642     0.9086     4249-JW-30      gatk
# 0     0.9573       0.8561     0.9039     4249-JW-32      gatk
# 0     0.9542       0.7093     0.8137     4249-JW-36      gatk
# 0     0.9587       0.9093     0.9333     4249-JW-38      gatk
# 0     0.9576       0.9082     0.9322     4249-JW-40      gatk
# 0     0.9577       0.9078     0.9321     4249-JW-42      gatk
# 0     0.9572       0.8791     0.9165     4249-JW-43      gatk
# 0     1.0000       0.9967     0.9983  NA12878_Bulk2      gatk

# %%
rtg_summary_df.to_csv("tracked_data/rtg_summary_all_samples.tsv", sep = "\t")

# %%
rtg_summary_df
# Out:
#   Threshold  True-pos-baseline  True-pos-call  False-pos  False-neg
# 0     0.9262       0.9084     0.9172     4249-JW-42    dragen
# 0     0.9212       0.8820     0.9012     4249-JW-43    dragen
# 0     1.0000       1.0000     1.0000  NA12878_Bulk2    dragen
# 0     0.9685       0.9018     0.9339     4249-JW-10  sentieon
# 0     0.9696       0.9234     0.9459     4249-JW-14  sentieon
# 0     0.9677       0.8842     0.9241     4249-JW-16  sentieon
# 0     0.9686       0.8954     0.9305     4249-JW-17  sentieon
# 0     0.9687       0.9210     0.9443     4249-JW-18  sentieon
# 0     0.9683       0.9268     0.9471     4249-JW-19  sentieon
# 0     0.9669       0.8328     0.8948     4249-JW-23  sentieon
# 0     0.9694       0.9348     0.9518     4249-JW-25  sentieon
# 0     0.9682       0.8656     0.9140     4249-JW-27  sentieon
# 0     0.9687       0.8610     0.9117     4249-JW-30  sentieon
# 0     0.9679       0.8531     0.9069     4249-JW-32  sentieon
# 0     0.9639       0.7082     0.8165     4249-JW-36  sentieon
# 0     0.9700       0.9050     0.9363     4249-JW-38  sentieon
# 0     0.9686       0.9042     0.9353     4249-JW-40  sentieon
# 0     0.9687       0.9046     0.9356     4249-JW-42  sentieon
# 0     0.9679       0.8760     0.9196     4249-JW-43  sentieon
# 0     1.0000       1.0000     1.0000  NA12878_Bulk2  sentieon
# 0     0.9575       0.9055     0.9308     4249-JW-10      gatk
# 0     0.9576       0.9278     0.9425     4249-JW-14      gatk
# 0     0.9572       0.8840     0.9191     4249-JW-16      gatk
# 0     0.9568       0.8982     0.9266     4249-JW-17      gatk
# 0     0.9576       0.9244     0.9407     4249-JW-18      gatk
# 0     0.9570       0.9307     0.9437     4249-JW-19      gatk
# 0     0.9565       0.8355     0.8919     4249-JW-23      gatk
# 0     0.9585       0.9387     0.9485     4249-JW-25      gatk
# 0     0.9572       0.8682     0.9105     4249-JW-27      gatk
# 0     0.9579       0.8642     0.9086     4249-JW-30      gatk
# 0     0.9573       0.8561     0.9039     4249-JW-32      gatk
# 0     0.9542       0.7093     0.8137     4249-JW-36      gatk
# 0     0.9587       0.9093     0.9333     4249-JW-38      gatk
# 0     0.9576       0.9082     0.9322     4249-JW-40      gatk
# 0     0.9577       0.9078     0.9321     4249-JW-42      gatk
# 0     0.9572       0.8791     0.9165     4249-JW-43      gatk
# 0     1.0000       0.9967     0.9983  NA12878_Bulk2      gatk

# %% [markdown]
# ### Comparing all samples to GIAB

# %% [markdown]
# We compare all samples in each VCF to the GIAB sample. This gives us an objectibve means for comparison between vendors

# %% [markdown]
# #### GATK

# %%
# !tracked_data/run_rtg.sh /home/rcarter/R_bioskryb_na12878_analysis/NA12878_comparison/HG001_GRCh38_GIAB_highconf_CG-IllFB-IllGATKHC-Ion-10X-SOLID_CHROM1-X_v.3.3.2_highconf_PGandRTGphasetransfer.vcf.gz HG001 scratch/nosubsampling_n16_gatk_joint_genotyping_gatk.snps_only.vcf.gz $gatk_joined_samplenames  giab_vs_n16_gatk "--vcf-score-field=INFO.AS_VQSLOD"
# Out:
# Threshold  True-pos-baseline  True-pos-call  False-pos  False-neg  Precision  Sensitivity  F-measure
# ----------------------------------------------------------------------------------------------------
#    -1.811            2834581        2834579     499181     784890     0.8503       0.7831     0.8153
#      None            2872912        2872878     575870     746559     0.8330       0.7937     0.8129
#
# Reference sequence chrY is used in calls but not in baseline.
# There were 9860 variants not thresholded in ROC data files due to missing or invalid AS_VQSLOD (INFO) values.
# Threshold  True-pos-baseline  True-pos-call  False-pos  False-neg  Precision  Sensitivity  F-measure
# ----------------------------------------------------------------------------------------------------
#    -1.923            
1_alt is used in calls but not in baseline.
# Reference sequence chr22_KI270878v1_alt is used in calls but not in baseline.
# Reference sequence chr22_KI270879v1_alt is used in calls but not in baseline.
# Reference sequence chr22_KI270876v1_alt is used in calls but not in baseline.
# Reference sequence chr22_KI270877v1_alt is used in calls but not in baseline.
# Reference sequence chr22_GL383583v2_alt is used in calls but not in baseline.
# Reference sequence chr22_GL383582v2_alt is used in calls but not in baseline.
# Reference sequence chrX_KI270880v1_alt is used in calls but not in baseline.
# Reference sequence chrX_KI270881v1_alt is used in calls but not in baseline.
# Reference sequence chr19_KI270882v1_alt is used in calls but not in baseline.
# Reference sequence chr19_KI270884v1_alt is used in calls but not in baseline.
# Reference sequence chr19_KI270885v1_alt is used in calls but not in baseline.
# Reference sequence chr19_KI270886v1_alt is used in calls but not in baseline.
# Reference sequence chr19_KI270887v1_alt is used in calls but not in baseline.
# Reference sequence chr19_KI270888v1_alt is used in calls but not in baseline.
# Reference sequence chr19_KI270890v1_alt is used in calls but not in baseline.
# Reference sequence chr1_KI270892v1_alt is used in calls but not in baseline.
# Reference sequence chr2_KI270894v1_alt is used in calls but not in baseline.
# Reference sequence chr2_KI270893v1_alt is used in calls but not in baseline.
# Reference sequence chr3_KI270895v1_alt is used in calls but not in baseline.
# Reference sequence chr4_KI270896v1_alt is used in calls but not in baseline.
# Reference sequence chr5_KI270897v1_alt is used in calls but not in baseline.
# Reference sequence chr5_KI270898v1_alt is used in calls but not in baseline.
# Reference sequence chr6_GL000251v2_alt is used in calls but not in baseline.
# Reference sequence chr7_KI270899v1_alt is used in calls but not in baseline.
# Reference sequence chr8_KI270901v1_alt is used in calls but not in baseline.
# Reference sequence chr8_KI270900v1_alt is used in calls but not in baseline.
# Reference sequence chr11_KI270902v1_alt is used in calls but not in baseline.
# Reference sequence chr11_KI270903v1_alt is used in calls but not in baseline.
# Reference sequence chr12_KI270904v1_alt is used in calls but not in baseline.
# Reference sequence chr15_KI270906v1_alt is used in calls but not in baseline.
# Reference sequence chr15_KI270905v1_alt is used in calls but not in baseline.
# Reference sequence chr17_KI270907v1_alt is used in calls but not in baseline.
# Reference sequence chr17_KI270910v1_alt is used in calls but not in baseline.
# Reference sequence chr17_KI270909v1_alt is used in calls but not in baseline.
# Reference sequence chr17_JH159148v1_alt is used in calls but not in baseline.
# Reference sequence chr17_KI270908v1_alt is used in calls but not in baseline.
# Reference sequence chr18_KI270912v1_alt is used in calls but not in baseline.
# Reference sequence chr18_KI270911v1_alt is used in calls but not in baseline.
# Reference sequence chr19_GL949747v2_alt is used in calls but not in baseline.
# Reference sequence chr22_KB663609v1_alt is used in calls but not in baseline.
# Reference sequence chrX_KI270913v1_alt is used in calls but not in baseline.
# Reference sequence chr19_KI270914v1_alt is used in calls but not in baseline.
# Reference sequence chr19_KI270916v1_alt is used in calls but not in baseline.
# Reference sequence chr19_KI270917v1_alt is used in calls but not in baseline.
# Reference sequence chr19_KI270918v1_alt is used in calls but not in baseline.
# Reference sequence chr19_KI270919v1_alt is used in calls but not in baseline.
# Reference sequence chr19_KI270920v1_alt is used in calls but not in baseline.
# Reference sequence chr19_KI270921v1_alt is used in calls but not in baseline.
# Reference sequence chr19_KI270922v1_alt is used in calls but not in baseline.
# Reference sequence chr19_KI270923v1_alt is used in calls but not in baseline.
# Reference sequence chr3_KI270924v1_alt is used in calls but not in baseline.
# Reference sequence chr4_KI270925v1_alt is used in calls but not in baseline.
# Reference sequence chr6_GL000252v2_alt is used in calls but not in baseline.
# Reference sequence chr8_KI270926v1_alt is used in calls but not in baseline.
# Reference sequence chr11_KI270927v1_alt is used in calls but not in baseline.
# Reference sequence chr19_GL949748v2_alt is used in calls but not in baseline.
# Reference sequence chr22_KI270928v1_alt is used in calls but not in baseline.
# Reference sequence chr19_KI270929v1_alt is used in calls but not in baseline.
# Reference sequence chr19_KI270930v1_alt is used in calls but not in baseline.
# Reference sequence chr19_KI270932v1_alt is used in calls but not in baseline.
# Reference sequence chr19_GL000209v2_alt is used in calls but not in baseline.
# Reference sequence chr3_KI270934v1_alt is used in calls but not in baseline.
# Reference sequence chr6_GL000253v2_alt is used in calls but not in baseline.
# Reference sequence chr19_GL949749v2_alt is used in calls but not in baseline.
# Reference sequence chr3_KI270935v1_alt is used in calls but not in baseline.
# Reference sequence chr6_GL000254v2_alt is used in calls but not in baseline.
# Reference sequence chr19_GL949750v2_alt is used in calls but not in baseline.
# Reference sequence chr3_KI270936v1_alt is used in calls but not in baseline.
# Reference sequence chr6_GL000255v2_alt is used in calls but not in baseline.
# Reference sequence chr19_GL949751v2_alt is used in calls but not in baseline.
# Reference sequence chr3_KI270937v1_alt is used in calls but not in baseline.
# Reference sequence chr6_GL000256v2_alt is used in calls but not in baseline.
# Reference sequence chr19_GL949752v1_alt is used in calls but not in baseline.
# Reference sequence chr6_KI270758v1_alt is used in calls but not in baseline.
# Reference sequence chr19_GL949753v2_alt is used in calls but not in baseline.
# Reference sequence chr19_KI270938v1_alt is used in calls but not in baseline.
# Reference sequence HLA-B*59:01:01:01 is used in calls but not in baseline.
# Reference sequence HLA-DQA1*01:03:01:01 is used in calls but not in baseline.
# Reference sequence HLA-DQA1*01:03:01:02 is used in calls but not in baseline.
# Reference sequence HLA-DQA1*01:04:01:02 is used in calls but not in baseline.
# Reference sequence HLA-DQA1*04:01:02:01 is used in calls but not in baseline.
# Reference sequence HLA-DQA1*05:03 is used in calls but not in baseline.
# Reference sequence HLA-DQB1*05:03:01:01 is used in calls but not in baseline.
# Reference sequence HLA-DRB1*01:02:01 is used in calls but not in baseline.
# Reference sequence HLA-DRB1*07:01:01:01 is used in calls but not in baseline.
# Reference sequence HLA-DRB1*07:01:01:02 is used in calls but not in baseline.
# Reference sequence HLA-DRB1*09:21 is used in calls but not in baseline.
# Reference sequence HLA-DRB1*10:01:01 is used in calls but not in baseline.
# Reference sequence HLA-DRB1*11:04:01 is used in calls but not in baseline.
# Reference sequence HLA-DRB1*12:01:01 is used in calls but not in baseline.
# Reference sequence HLA-DRB1*12:17 is used in calls but not in baseline.
# Reference sequence HLA-DRB1*13:02:01 is used in calls but not in baseline.
# Reference sequence HLA-DRB1*15:01:01:01 is used in calls but not in baseline.
# Reference sequence HLA-DRB1*15:01:01:02 is used in calls but not in baseline.
# Reference sequence HLA-DRB1*15:02:01 is used in calls but not in baseline.
# Reference sequence HLA-DRB1*15:03:01:01 is used in calls but not in baseline.
# There were 24 variants not thresholded in ROC data files due to missing or invalid GQ (FORMAT) values.

# %%
# !tracked_data/run_rtg.sh /home/rcarter/R_bioskryb_na12878_analysis/NA12878_comparison/HG001_GRCh38_GIAB_highconf_CG-IllFB-IllGATKHC-Ion-10X-SOLID_CHROM1-X_v.3.3.2_highconf_PGandRTGphasetransfer.vcf.gz HG001 scratch/dragen-joint.hard-filtered.snps_only.vcf.gz 4249-JW-10_combined,4249-JW-27_combined all_variants_giab_vs_n16_dragen  "--vcf-score-field=GQ --all-records"
#!tracked_data/run_rtg.sh scratch/dragen-joint.hard-filtered.snps_only.vcf.gz NA12878-Bulk2-merged-n450x10e6 scratch/dragen-joint.hard-filtered.snps_only.vcf.gz 4249-JW-10_combined,4249-JW-27_combined all_variants_n16_dragen  "--vcf-score-field=GQ  --all-records"
# Out:
# Threshold  True-pos-baseline  True-pos-call  False-pos  False-neg  Precision  Sensitivity  F-measure
# ----------------------------------------------------------------------------------------------------
#     5.000            2736619        2736590     994861     882852     0.7334       0.7561     0.7446
#      None            2780070        2780039    1111569     839401     0.7144       0.7681     0.7403
#
# Reference sequence chrY is used in calls but not in baseline.
# Reference sequence chrM is used in calls but not in baseline.
# Reference sequence chr1_KI270706v1_random is used in calls but not in baseline.
# Reference sequence chr1_KI270707v1_random is used in calls but not in baseline.
# Reference sequence chr1_KI270708v1_random is used in calls but not in baseline.
# Reference sequence chr1_KI270709v1_random is used in calls but not in baseline.
# Reference sequence chr1_KI270710v1_random is used in calls but not in baseline.
# Reference sequence chr1_KI270711v1_random is used in calls but not in baseline.
# Reference sequence chr1_KI270712v1_random is used in calls but not in baseline.
# Reference sequence chr1_KI270713v1_random is used in calls but not in baseline.
# Reference sequence chr1_KI270714v1_random is used in calls but not in baseline.
# Reference sequence chr2_KI270715v1_random is used in calls but not in baseline.
# Reference sequence chr2_KI270716v1_random is used in calls but not in baseline.
# Reference sequence chr3_GL000221v1_random is used in calls but not in baseline.
# Reference sequence chr4_GL000008v2_random is used in calls but not in baseline.
# Reference sequence chr5_GL000208v1_random is used in calls but not in baseline.
# Reference sequence chr9_KI270717v1_random is used in calls but not in baseline.
# Reference sequence chr9_KI270718v1_random is used in calls but not in baseline.
# Reference sequence chr9_KI270719v1_random is used in calls but not in baseline.
# Reference sequence chr9_KI270720v1_random is used in calls but not in baseline.
# Reference sequence chr11_KI270721v1_random is used in calls but not in baseline.
# Reference sequence chr14_GL000009v2_random is used in calls but not in baseline.
# Reference sequence chr14_GL000225v1_random is used in calls but not in baseline.
# Reference sequence chr14_KI270722v1_random is used in calls but not in baseline.
# Reference sequence chr14_GL000194v1_random is used in calls but not in baseline.
# Reference sequence chr14_KI270723v1_random is used in calls but not in baseline.
# Reference sequence chr14_KI270724v1_random is used in calls but not in baseline.
# Reference sequence chr14_KI270725v1_random is used in calls but not in baseline.
# Reference sequence chr14_KI270726v1_random is used in calls but not in baseline.
# Reference sequence chr15_KI270727v1_random is used in calls but not in baseline.
# Reference sequence chr16_KI270728v1_random is used in calls but not in baseline.
# Reference sequence chr17_GL000205v2_random is used in calls but not in baseline.
# Reference sequence chr17_KI270729v1_random is used in calls but not in baseline.
# Reference sequence chr17_KI270730v1_random is used in calls but not in baseline.
# Reference sequence chr22_KI270731v1_random is used in calls but not in baseline.
# Reference sequence chr22_KI270732v1_random is used in calls but not in baseline.
# Reference sequence chr22_KI270733v1_random is used in calls but not in baseline.
# Reference sequence chr22_KI270734v1_random is used in calls but not in baseline.
# Reference sequence chr22_KI270735v1_random is used in calls but not in baseline.
# Reference sequence chr22_KI270736v1_random is used in calls but not in baseline.
# Reference sequence chr22_KI270737v1_random is used in calls but not in baseline.
# Reference sequence chr22_KI270738v1_random is used in calls but not in baseline.
# Reference sequence chr22_KI270739v1_random is used in calls but not in baseline.
# Reference sequence chrUn_KI270302v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270304v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270303v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270305v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270322v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270320v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270310v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270316v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270315v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270312v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270311v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270317v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270412v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270411v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270414v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270419v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270418v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270420v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270424v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270417v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270422v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270423v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270425v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270429v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270442v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270466v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270465v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270467v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270435v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270438v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270468v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270510v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270509v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270518v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270508v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270516v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270512v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270519v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270522v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270511v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270515v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270507v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270517v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270529v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270528v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270530v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270539v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270538v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270544v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270583v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270587v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270580v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270581v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270579v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270589v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270590v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270584v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270582v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270588v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270593v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270591v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270330v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270329v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270334v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270333v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270340v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270336v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270337v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270363v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270364v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270362v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270366v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270378v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270389v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270390v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270387v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270395v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270396v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270388v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270394v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270386v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270391v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270383v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270393v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270384v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270392v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270381v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270385v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270382v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270374v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270372v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270373v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270375v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270371v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270448v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270521v1 is used in calls but not in baseline.
# Reference sequence chrUn_GL000195v1 is used in calls but not in baseline.
# Reference sequence chrUn_GL000219v1 is used in calls but not in baseline.
# Reference sequence chrUn_GL000220v1 is used in calls but not in baseline.
# Reference sequence chrUn_GL000224v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270741v1 is used in calls but not in baseline.
# Reference sequence chrUn_GL000226v1 is used in calls but not in baseline.
# Reference sequence chrUn_GL000213v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270743v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270744v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270745v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270746v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270747v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270748v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270749v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270750v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270751v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270753v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270754v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270755v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270756v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270757v1 is used in calls but not in baseline.
# Reference sequence chrUn_GL000214v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270742v1 is used in calls but not in baseline.
# Reference sequence chrUn_GL000216v2 is used in calls but not in baseline.
# Reference sequence chrUn_GL000218v1 is used in calls but not in baseline.
# Reference sequence chr1_KI270762v1_alt is used in calls but not in baseline.
# Reference sequence chr1_KI270766v1_alt is used in calls but not in baseline.
# Reference sequence chr1_KI270760v1_alt is used in calls but not in baseline.
# Reference sequence chr1_KI270765v1_alt is used in calls but not in baseline.
# Reference sequence chr1_GL383518v1_alt is used in calls but not in baseline.
# Reference sequence chr1_GL383519v1_alt is used in calls but not in baseline.
# Reference sequence chr1_GL383520v2_alt is used in calls but not in baseline.
# Reference sequence chr1_KI270764v1_alt is used in calls but not in baseline.
# Reference sequence chr1_KI270763v1_alt is used in calls but not in baseline.
# Reference sequence chr1_KI270759v1_alt is used in calls but not in baseline.
# Reference sequence chr1_KI270761v1_alt is used in calls but not in baseline.
# Reference sequence chr2_KI270770v1_alt is used in calls but not in baseline.
# Reference sequence chr2_KI270773v1_alt is used in calls but not in baseline.
# Reference sequence chr2_KI270774v1_alt is used in calls but not in baseline.
# Reference sequence chr2_KI270769v1_alt is used in calls but not in baseline.
# Reference sequence chr2_GL383521v1_alt is used in calls but not in baseline.
# Reference sequence chr2_KI270772v1_alt is used in calls but not in baseline.
# Reference sequence chr2_KI270775v1_alt is used in calls but not in baseline.
# Reference sequence chr2_KI270771v1_alt is used in calls but not in baseline.
# Reference sequence chr2_KI270768v1_alt is used in calls but not in baseline.
# Reference sequence chr2_GL582966v2_alt is used in calls but not in baseline.
# Reference sequence chr2_GL383522v1_alt is used in calls but not in baseline.
# Reference sequence chr2_KI270776v1_alt is used in calls but not in baseline.
# Reference sequence chr2_KI270767v1_alt is used in calls but not in baseline.
# Reference sequence chr3_JH636055v2_alt is used in calls but not in baseline.
# Reference sequence chr3_KI270783v1_alt is used in calls but not in baseline.
# Reference sequence chr3_KI270780v1_alt is used in calls but not in baseline.
# Reference sequence chr3_GL383526v1_alt is used in calls but not in baseline.
# Reference sequence chr3_KI270777v1_alt is used in calls but not in baseline.
# Reference sequence chr3_KI270778v1_alt is used in calls but not in baseline.
# Reference sequence chr3_KI270781v1_alt is used in calls but not in baseline.
# Reference sequence chr3_KI270779v1_alt is used in calls but not in baseline.
# Reference sequence chr3_KI270782v1_alt is used in calls but not in baseline.
# Reference sequence chr3_KI270784v1_alt is used in calls but not in baseline.
# Reference sequence chr4_KI270790v1_alt is used in calls but not in baseline.
# Reference sequence chr4_GL383528v1_alt is used in calls but not in baseline.
# Reference sequence chr4_KI270787v1_alt is used in calls but not in baseline.
# Reference sequence chr4_GL000257v2_alt is used in calls but not in baseline.
# Reference sequence chr4_KI270788v1_alt is used in calls but not in baseline.
# Reference sequence chr4_GL383527v1_alt is used in calls but not in baseline.
# Reference sequence chr4_KI270785v1_alt is used in calls but not in baseline.
# Reference sequence chr4_KI270789v1_alt is used in calls but not in baseline.
# Reference sequence chr4_KI270786v1_alt is used in calls but not in baseline.
# Reference sequence chr5_KI270793v1_alt is used in calls but not in baseline.
# Reference sequence chr5_KI270792v1_alt is used in calls but not in baseline.
# Reference sequence chr5_KI270791v1_alt is used in calls but not in baseline.
# Reference sequence chr5_GL383532v1_alt is used in calls but not in baseline.
# Reference sequence chr5_GL949742v1_alt is used in calls but not in baseline.
# Reference sequence chr5_KI270794v1_alt is used in calls but not in baseline.
# Reference sequence chr5_GL339449v2_alt is used in calls but not in baseline.
# Reference sequence chr5_GL383530v1_alt is used in calls but not in baseline.
# Reference sequence chr5_KI270796v1_alt is used in calls but not in baseline.
# Reference sequence chr5_GL383531v1_alt is used in calls but not in baseline.
# Reference sequence chr5_KI270795v1_alt is used in calls but not in baseline.
# Reference sequence chr6_GL000250v2_alt is used in calls but not in baseline.
# Reference sequence chr6_KI270800v1_alt is used in calls but not in baseline.
# Reference sequence chr6_KI270799v1_alt is used in calls but not in baseline.
# Reference sequence chr6_GL383533v1_alt is used in calls but not in baseline.
# Reference sequence chr6_KI270801v1_alt is used in calls but not in baseline.
# Reference sequence chr6_KI270802v1_alt is used in calls but not in baseline.
# Reference sequence chr6_KB021644v2_alt is used in calls but not in baseline.
# Reference sequence chr6_KI270797v1_alt is used in calls but not in baseline.
# Reference sequence chr6_KI270798v1_alt is used in calls but not in baseline.
# Reference sequence chr7_KI270804v1_alt is used in calls but not in baseline.
# Reference sequence chr7_KI270809v1_alt is used in calls but not in baseline.
# Reference sequence chr7_KI270806v1_alt is used in calls but not in baseline.
# Reference sequence chr7_GL383534v2_alt is used in calls but not in baseline.
# Reference sequence chr7_KI270803v1_alt is used in calls but not in baseline.
# Reference sequence chr7_KI270808v1_alt is used in calls but not in baseline.
# Reference sequence chr7_KI270807v1_alt is used in calls but not in baseline.
# Reference sequence chr7_KI270805v1_alt is used in calls but not in baseline.
# Reference sequence chr8_KI270818v1_alt is used in calls but not in baseline.
# Reference sequence chr8_KI270812v1_alt is used in calls but not in baseline.
# Reference sequence chr8_KI270811v1_alt is used in calls but not in baseline.
# Reference sequence chr8_KI270821v1_alt is used in calls but not in baseline.
# Reference sequence chr8_KI270813v1_alt is used in calls but not in baseline.
# Reference sequence chr8_KI270822v1_alt is used in calls but not in baseline.
# Reference sequence chr8_KI270814v1_alt is used in calls but not in baseline.
# Reference sequence chr8_KI270810v1_alt is used in calls but not in baseline.
# Reference sequence chr8_KI270819v1_alt is used in calls but not in baseline.
# Reference sequence chr8_KI270820v1_alt is used in calls but not in baseline.
# Reference sequence chr8_KI270817v1_alt is used in calls but not in baseline.
# Reference sequence chr8_KI270816v1_alt is used in calls but not in baseline.
# Reference sequence chr8_KI270815v1_alt is used in calls but not in baseline.
# Reference sequence chr9_GL383539v1_alt is used in calls but not in baseline.
# Reference sequence chr9_GL383540v1_alt is used in calls but not in baseline.
# Reference sequence chr9_GL383541v1_alt is used in calls but not in baseline.
# Reference sequence chr9_GL383542v1_alt is used in calls but not in baseline.
# Reference sequence chr9_KI270823v1_alt is used in calls but not in baseline.
# Reference sequence chr10_GL383545v1_alt is used in calls but not in baseline.
# Reference sequence chr10_KI270824v1_alt is used in calls but not in baseline.
# Reference sequence chr10_GL383546v1_alt is used in calls but not in baseline.
# Reference sequence chr10_KI270825v1_alt is used in calls but not in baseline.
# Reference sequence chr11_KI270832v1_alt is used in calls but not in baseline.
# Reference sequence chr11_KI270830v1_alt is used in calls but not in baseline.
# Reference sequence chr11_KI270831v1_alt is used in calls but not in baseline.
# Reference sequence chr11_KI270829v1_alt is used in calls but not in baseline.
# Reference sequence chr11_GL383547v1_alt is used in calls but not in baseline.
# Reference sequence chr11_JH159136v1_alt is used in calls but not in baseline.
# Reference sequence chr11_JH159137v1_alt is used in calls but not in baseline.
# Reference sequence chr11_KI270827v1_alt is used in calls but not in baseline.
# Reference sequence chr11_KI270826v1_alt is used in calls but not in baseline.
# Reference sequence chr12_GL877875v1_alt is used in calls but not in baseline.
# Reference sequence chr12_GL877876v1_alt is used in calls but not in baseline.
# Reference sequence chr12_KI270837v1_alt is used in calls but not in baseline.
# Reference sequence chr12_GL383549v1_alt is used in calls but not in baseline.
# Reference sequence chr12_KI270835v1_alt is used in calls but not in baseline.
# Reference sequence chr12_GL383550v2_alt is used in calls but not in baseline.
# Reference sequence chr12_GL383552v1_alt is used in calls but not in baseline.
# Reference sequence chr12_GL383553v2_alt is used in calls but not in baseline.
# Reference sequence chr12_KI270834v1_alt is used in calls but not in baseline.
# Reference sequence chr12_GL383551v1_alt is used in calls but not in baseline.
# Reference sequence chr12_KI270833v1_alt is used in calls but not in baseline.
# Reference sequence chr12_KI270836v1_alt is used in calls but not in baseline.
# Reference sequence chr13_KI270840v1_alt is used in calls but not in baseline.
# Reference sequence chr13_KI270839v1_alt is used in calls but not in baseline.
# Reference sequence chr13_KI270843v1_alt is used in calls but not in baseline.
# Reference sequence chr13_KI270841v1_alt is used in calls but not in baseline.
# Reference sequence chr13_KI270838v1_alt is used in calls but not in baseline.
# Reference sequence chr13_KI270842v1_alt is used in calls but not in baseline.
# Reference sequence chr14_KI270844v1_alt is used in calls but not in baseline.
# Reference sequence chr14_KI270847v1_alt is used in calls but not in baseline.
# Reference sequence chr14_KI270845v1_alt is used in calls but not in baseline.
# Reference sequence chr14_KI270846v1_alt is used in calls but not in baseline.
# Reference sequence chr15_KI270852v1_alt is used in calls but not in baseline.
# Reference sequence chr15_KI270851v1_alt is used in calls but not in baseline.
# Reference sequence chr15_KI270848v1_alt is used in calls but not in baseline.
# Reference sequence chr15_GL383554v1_alt is used in calls but not in baseline.
# Reference sequence chr15_KI270849v1_alt is used in calls but not in baseline.
# Reference sequence chr15_GL383555v2_alt is used in calls but not in baseline.
# Reference sequence chr15_KI270850v1_alt is used in calls but not in baseline.
# Reference sequence chr16_KI270854v1_alt is used in calls but not in baseline.
# Reference sequence chr16_KI270856v1_alt is used in calls but not in baseline.
# Reference sequence chr16_KI270855v1_alt is used in calls but not in baseline.
# Reference sequence chr16_KI270853v1_alt is used in calls but not in baseline.
# Reference sequence chr16_GL383556v1_alt is used in calls but not in baseline.
# Reference sequence chr16_GL383557v1_alt is used in calls but not in baseline.
# Reference sequence chr17_GL383563v3_alt is used in calls but not in baseline.
# Reference sequence chr17_KI270862v1_alt is used in calls but not in baseline.
# Reference sequence chr17_KI270861v1_alt is used in calls but not in baseline.
# Reference sequence chr17_KI270857v1_alt is used in calls but not in baseline.
# Reference sequence chr17_JH159146v1_alt is used in calls but not in baseline.
# Reference sequence chr17_JH159147v1_alt is used in calls but not in baseline.
# Reference sequence chr17_GL383564v2_alt is used in calls but not in baseline.
# Reference sequence chr17_GL000258v2_alt is used in calls but not in baseline.
# Reference sequence chr17_GL383565v1_alt is used in calls but not in baseline.
# Reference sequence chr17_KI270858v1_alt is used in calls but not in baseline.
# Reference sequence chr17_KI270859v1_alt is used in calls but not in baseline.
# Reference sequence chr17_GL383566v1_alt is used in calls but not in baseline.
# Reference sequence chr17_KI270860v1_alt is used in calls but not in baseline.
# Reference sequence chr18_KI270864v1_alt is used in calls but not in baseline.
# Reference sequence chr18_GL383567v1_alt is used in calls but not in baseline.
# Reference sequence chr18_GL383570v1_alt is used in calls but not in baseline.
# Reference sequence chr18_GL383571v1_alt is used in calls but not in baseline.
# Reference sequence chr18_GL383568v1_alt is used in calls but not in baseline.
# Reference sequence chr18_GL383569v1_alt is used in calls but not in baseline.
# Reference sequence chr18_GL383572v1_alt is used in calls but not in baseline.
# Reference sequence chr18_KI270863v1_alt is used in calls but not in baseline.
# Reference sequence chr19_KI270868v1_alt is used in calls but not in baseline.
# Reference sequence chr19_KI270865v1_alt is used in calls but not in baseline.
# Reference sequence chr19_GL383573v1_alt is used in calls but not in baseline.
# Reference sequence chr19_GL383575v2_alt is used in calls but not in baseline.
# Reference sequence chr19_GL383576v1_alt is used in calls but not in baseline.
# Reference sequence chr19_GL383574v1_alt is used in calls but not in baseline.
# Reference sequence chr19_KI270866v1_alt is used in calls but not in baseline.
# Reference sequence chr19_KI270867v1_alt is used in calls but not in baseline.
# Reference sequence chr19_GL949746v1_alt is used in calls but not in baseline.
# Reference sequence chr20_GL383577v2_alt is used in calls but not in baseline.
# Reference sequence chr20_KI270869v1_alt is used in calls but not in baseline.
# Reference sequence chr20_KI270871v1_alt is used in calls but not in baseline.
# Reference sequence chr20_KI270870v1_alt is used in calls but not in baseline.
# Reference sequence chr21_GL383578v2_alt is used in calls but not in baseline.
# Reference sequence chr21_KI270874v1_alt is used in calls but not in baseline.
# Reference sequence chr21_KI270873v1_alt is used in calls but not in baseline.
# Reference sequence chr21_GL383579v2_alt is used in calls but not in baseline.
# Reference sequence chr21_GL383580v2_alt is used in calls but not in baseline.
# Reference sequence chr21_GL383581v2_alt is used in calls but not in baseline.
# Reference sequence chr21_KI270872v1_alt is used in calls but not in baseline.
# Reference sequence chr22_KI270875v1_alt is used in calls but not in baseline.
# Reference sequence chr22_KI270878v1_alt is used in calls but not in baseline.
# Reference sequence chr22_KI270879v1_alt is used in calls but not in baseline.
# Reference sequence chr22_KI270876v1_alt is used in calls but not in baseline.
# Reference sequence chr22_KI270877v1_alt is used in calls but not in baseline.
# Reference sequence chr22_GL383583v2_alt is used in calls but not in baseline.
# Reference sequence chr22_GL383582v2_alt is used in calls but not in baseline.
# Reference sequence chrX_KI270880v1_alt is used in calls but not in baseline.
# Reference sequence chrX_KI270881v1_alt is used in calls but not in baseline.
# Reference sequence chr19_KI270882v1_alt is used in calls but not in baseline.
# Reference sequence chr19_KI270884v1_alt is used in calls but not in baseline.
# Reference sequence chr19_KI270885v1_alt is used in calls but not in baseline.
# Reference sequence chr19_KI270886v1_alt is used in calls but not in baseline.
# Reference sequence chr19_KI270887v1_alt is used in calls but not in baseline.
# Reference sequence chr19_KI270888v1_alt is used in calls but not in baseline.
# Reference sequence chr19_KI270890v1_alt is used in calls but not in baseline.
# Reference sequence chr1_KI270892v1_alt is used in calls but not in baseline.
# Reference sequence chr2_KI270894v1_alt is used in calls but not in baseline.
# Reference sequence chr2_KI270893v1_alt is used in calls but not in baseline.
# Reference sequence chr3_KI270895v1_alt is used in calls but not in baseline.
# Reference sequence chr4_KI270896v1_alt is used in calls but not in baseline.
# Reference sequence chr5_KI270897v1_alt is used in calls but not in baseline.
# Reference sequence chr5_KI270898v1_alt is used in calls but not in baseline.
# Reference sequence chr6_GL000251v2_alt is used in calls but not in baseline.
# Reference sequence chr7_KI270899v1_alt is used in calls but not in baseline.
# Reference sequence chr8_KI270901v1_alt is used in calls but not in baseline.
# Reference sequence chr8_KI270900v1_alt is used in calls but not in baseline.
# Reference sequence chr11_KI270902v1_alt is used in calls but not in baseline.
# Reference sequence chr11_KI270903v1_alt is used in calls but not in baseline.
# Reference sequence chr12_KI270904v1_alt is used in calls but not in baseline.
# Reference sequence chr15_KI270906v1_alt is used in calls but not in baseline.
# Reference sequence chr15_KI270905v1_alt is used in calls but not in baseline.
# Reference sequence chr17_KI270907v1_alt is used in calls but not in baseline.
# Reference sequence chr17_KI270910v1_alt is used in calls but not in baseline.
# Reference sequence chr17_KI270909v1_alt is used in calls but not in baseline.
# Reference sequence chr17_JH159148v1_alt is used in calls but not in baseline.
# Reference sequence chr17_KI270908v1_alt is used in calls but not in baseline.
# Reference sequence chr18_KI270912v1_alt is used in calls but not in baseline.
# Reference sequence chr18_KI270911v1_alt is used in calls but not in baseline.
# Reference sequence chr19_GL949747v2_alt is used in calls but not in baseline.
# Reference sequence chr22_KB663609v1_alt is used in calls but not in baseline.
# Reference sequence chrX_KI270913v1_alt is used in calls but not in baseline.
# Reference sequence chr19_KI270914v1_alt is used in calls but not in baseline.
# Reference sequence chr19_KI270916v1_alt is used in calls but not in baseline.
# Reference sequence chr19_KI270917v1_alt is used in calls but not in baseline.
# Reference sequence chr19_KI270918v1_alt is used in calls but not in baseline.
# Reference sequence chr19_KI270919v1_alt is used in calls but not in baseline.
# Reference sequence chr19_KI270920v1_alt is used in calls but not in baseline.
# Reference sequence chr19_KI270921v1_alt is used in calls but not in baseline.
# Reference sequence chr19_KI270922v1_alt is used in calls but not in baseline.
# Reference sequence chr19_KI270923v1_alt is used in calls but not in baseline.
# Reference sequence chr3_KI270924v1_alt is used in calls but not in baseline.
# Reference sequence chr4_KI270925v1_alt is used in calls but not in baseline.
# Reference sequence chr6_GL000252v2_alt is used in calls but not in baseline.
# Reference sequence chr8_KI270926v1_alt is used in calls but not in baseline.
# Reference sequence chr11_KI270927v1_alt is used in calls but not in baseline.
# Reference sequence chr19_GL949748v2_alt is used in calls but not in baseline.
# Reference sequence chr22_KI270928v1_alt is used in calls but not in baseline.
# Reference sequence chr19_KI270929v1_alt is used in calls but not in baseline.
# Reference sequence chr19_KI270930v1_alt is used in calls but not in baseline.
# Reference sequence chr19_KI270932v1_alt is used in calls but not in baseline.
# Reference sequence chr19_GL000209v2_alt is used in calls but not in baseline.
# Reference sequence chr3_KI270934v1_alt is used in calls but not in baseline.
# Reference sequence chr6_GL000253v2_alt is used in calls but not in baseline.
# Reference sequence chr19_GL949749v2_alt is used in calls but not in baseline.
# Reference sequence chr3_KI270935v1_alt is used in calls but not in baseline.
# Reference sequence chr6_GL000254v2_alt is used in calls but not in baseline.
# Reference sequence chr19_GL949750v2_alt is used in calls but not in baseline.
# Reference sequence chr3_KI270936v1_alt is used in calls but not in baseline.
# Reference sequence chr6_GL000255v2_alt is used in calls but not in baseline.
# Reference sequence chr19_GL949751v2_alt is used in calls but not in baseline.
# Reference sequence chr3_KI270937v1_alt is used in calls but not in baseline.
# Reference sequence chr6_GL000256v2_alt is used in calls but not in baseline.
# Reference sequence chr19_GL949752v1_alt is used in calls but not in baseline.
# Reference sequence chr6_KI270758v1_alt is used in calls but not in baseline.
# Reference sequence chr19_GL949753v2_alt is used in calls but not in baseline.
# Reference sequence chr19_KI270938v1_alt is used in calls but not in baseline.
# Reference sequence HLA-B*59:01:01:01 is used in calls but not in baseline.
# Reference sequence HLA-DQA1*01:03:01:01 is used in calls but not in baseline.
# Reference sequence HLA-DQA1*01:03:01:02 is used in calls but not in baseline.
# Reference sequence HLA-DQA1*01:04:01:02 is used in calls but not in baseline.
# Reference sequence HLA-DQA1*04:01:02:01 is used in calls but not in baseline.
# Reference sequence HLA-DQA1*05:03 is used in calls but not in baseline.
# Reference sequence HLA-DQB1*05:03:01:01 is used in calls but not in baseline.
# Reference sequence HLA-DRB1*01:02:01 is used in calls but not in baseline.
# Reference sequence HLA-DRB1*07:01:01:01 is used in calls but not in baseline.
# Reference sequence HLA-DRB1*07:01:01:02 is used in calls but not in baseline.
# Reference sequence HLA-DRB1*09:21 is used in calls but not in baseline.
# Reference sequence HLA-DRB1*10:01:01 is used in calls but not in baseline.
# Reference sequence HLA-DRB1*11:04:01 is used in calls but not in baseline.
# Reference sequence HLA-DRB1*12:01:01 is used in calls but not in baseline.
# Reference sequence HLA-DRB1*12:17 is used in calls but not in baseline.
# Reference sequence HLA-DRB1*13:02:01 is used in calls but not in baseline.
# Reference sequence HLA-DRB1*15:01:01:01 is used in calls but not in baseline.
# Reference sequence HLA-DRB1*15:01:01:02 is used in calls but not in baseline.
# Reference sequence HLA-DRB1*15:02:01 is used in calls but not in baseline.
# Reference sequence HLA-DRB1*15:03:01:01 is used in calls but not in baseline.
# There were 529 variants not thresholded in ROC data files due to missing or invalid GQ (FORMAT) values.
# Threshold  True-pos-baseline  True-pos-call  False-pos  False-neg  Precision  Sensitivity  F-measure
# ----------------------------------------------------------------------------------------------------
#     5.000            2855901        2855862     992862     763570     0.7420       0.7890     0.7648
#      None            2890796        2890758    1113486     728675     0.7219       0.7987     0.7584
#
# Reference sequence chrY is used in calls but not in baseline.
# Reference sequence chrM is used in calls but not in baseline.
# Reference sequence chr1_KI270706v1_random is used in calls but not in baseline.
# Reference sequence chr1_KI270707v1_random is used in calls but not in baseline.
# Reference sequence chr1_KI270708v1_random is used in calls but not in baseline.
# Reference sequence chr1_KI270709v1_random is used in calls but not in baseline.
# Reference sequence chr1_KI270710v1_random is used in calls but not in baseline.
# Reference sequence chr1_KI270711v1_random is used in calls but not in baseline.
# Reference sequence chr1_KI270712v1_random is used in calls but not in baseline.
# Reference sequence chr1_KI270713v1_random is used in calls but not in baseline.
# Reference sequence chr1_KI270714v1_random is used in calls but not in baseline.
# Reference sequence chr2_KI270715v1_random is used in calls but not in baseline.
# Reference sequence chr2_KI270716v1_random is used in calls but not in baseline.
# Reference sequence chr3_GL000221v1_random is used in calls but not in baseline.
# Reference sequence chr4_GL000008v2_random is used in calls but not in baseline.
# Reference sequence chr5_GL000208v1_random is used in calls but not in baseline.
# Reference sequence chr9_KI270717v1_random is used in calls but not in baseline.
# Reference sequence chr9_KI270718v1_random is used in calls but not in baseline.
# Reference sequence chr9_KI270719v1_random is used in calls but not in baseline.
# Reference sequence chr9_KI270720v1_random is used in calls but not in baseline.
# Reference sequence chr11_KI270721v1_random is used in calls but not in baseline.
# Reference sequence chr14_GL000009v2_random is used in calls but not in baseline.
# Reference sequence chr14_GL000225v1_random is used in calls but not in baseline.
# Reference sequence chr14_KI270722v1_random is used in calls but not in baseline.
# Reference sequence chr14_GL000194v1_random is used in calls but not in baseline.
# Reference sequence chr14_KI270723v1_random is used in calls but not in baseline.
# Reference sequence chr14_KI270724v1_random is used in calls but not in baseline.
# Reference sequence chr14_KI270725v1_random is used in calls but not in baseline.
# Reference sequence chr14_KI270726v1_random is used in calls but not in baseline.
# Reference sequence chr15_KI270727v1_random is used in calls but not in baseline.
# Reference sequence chr16_KI270728v1_random is used in calls but not in baseline.
# Reference sequence chr17_GL000205v2_random is used in calls but not in baseline.
# Reference sequence chr17_KI270729v1_random is used in calls but not in baseline.
# Reference sequence chr17_KI270730v1_random is used in calls but not in baseline.
# Reference sequence chr22_KI270731v1_random is used in calls but not in baseline.
# Reference sequence chr22_KI270732v1_random is used in calls but not in baseline.
# Reference sequence chr22_KI270733v1_random is used in calls but not in baseline.
# Reference sequence chr22_KI270734v1_random is used in calls but not in baseline.
# Reference sequence chr22_KI270735v1_random is used in calls but not in baseline.
# Reference sequence chr22_KI270736v1_random is used in calls but not in baseline.
# Reference sequence chr22_KI270737v1_random is used in calls but not in baseline.
# Reference sequence chr22_KI270738v1_random is used in calls but not in baseline.
# Reference sequence chr22_KI270739v1_random is used in calls but not in baseline.
# Reference sequence chrUn_KI270302v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270304v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270303v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270305v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270322v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270320v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270310v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270316v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270315v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270312v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270311v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270317v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270412v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270411v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270414v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270419v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270418v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270420v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270424v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270417v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270422v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270423v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270425v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270429v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270442v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270466v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270465v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270467v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270435v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270438v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270468v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270510v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270509v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270518v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270508v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270516v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270512v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270519v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270522v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270511v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270515v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270507v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270517v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270529v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270528v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270530v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270539v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270538v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270544v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270583v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270587v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270580v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270581v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270579v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270589v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270590v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270584v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270582v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270588v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270593v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270591v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270330v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270329v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270334v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270333v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270340v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270336v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270337v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270363v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270364v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270362v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270366v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270378v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270389v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270390v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270387v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270395v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270396v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270388v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270394v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270386v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270391v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270383v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270393v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270384v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270392v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270381v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270385v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270382v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270374v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270372v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270373v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270375v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270371v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270448v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270521v1 is used in calls but not in baseline.
# Reference sequence chrUn_GL000195v1 is used in calls but not in baseline.
# Reference sequence chrUn_GL000219v1 is used in calls but not in baseline.
# Reference sequence chrUn_GL000220v1 is used in calls but not in baseline.
# Reference sequence chrUn_GL000224v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270741v1 is used in calls but not in baseline.
# Reference sequence chrUn_GL000226v1 is used in calls but not in baseline.
# Reference sequence chrUn_GL000213v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270743v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270744v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270745v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270746v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270747v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270748v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270749v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270750v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270751v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270753v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270754v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270755v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270756v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270757v1 is used in calls but not in baseline.
# Reference sequence chrUn_GL000214v1 is used in calls but not in baseline.
# Reference sequence chrUn_KI270742v1 is used in calls but not in baseline.
# Reference sequence chrUn_GL000216v2 is used in calls but not in baseline.
# Reference sequence chrUn_GL000218v1 is used in calls but not in baseline.
# Reference sequence chr1_KI270762v1_alt is used in calls but not in baseline.
# Reference sequence chr1_KI270766v1_alt is used in calls but not in baseline.
# Reference sequence chr1_KI270760v1_alt is used in calls but not in baseline.
# Reference sequence chr1_KI270765v1_alt is used in calls but not in baseline.
# Reference sequence chr1_GL383518v1_alt is used in calls but not in baseline.
# Reference sequence chr1_GL383519v1_alt is used in calls but not in baseline.
# Reference sequence chr1_GL383520v2_alt is used in calls but not in baseline.
# Reference sequence chr1_KI270764v1_alt is used in calls but not in baseline.
# Reference sequence chr1_KI270763v1_alt is used in calls but not in baseline.
# Reference sequence chr1_KI270759v1_alt is used in calls but not in baseline.
# Reference sequence chr1_KI270761v1_alt is used in calls but not in baseline.
# Reference sequence chr2_KI270770v1_alt is used in calls but not in baseline.
# Reference sequence chr2_KI270773v1_alt is used in calls but not in baseline.
# ...
# Reference sequence chr8_KI270818v1_alt is used in calls but not in baseline.
# Reference sequence chr8_KI270812v1_alt is used in calls but not in baseline.
# Reference sequence chr8_KI270811v1_alt is used in calls but not in baseline.
# Reference sequence chr8_KI270821v1_alt is used in calls but not in baseline.
# Reference sequence chr8_KI270813v1_alt is used in calls but not in baseline.
# Reference sequence chr8_KI270822v1_alt is used in calls but not in baseline.
# Reference sequence chr8_KI270814v1_alt is used in calls but not in baseline.
# Reference sequence chr8_KI270810v1_alt is used in calls but not in baseline.
# Reference sequence chr8_KI270819v1_alt is used in calls but not in baseline.
# Reference sequence chr8_KI270820v1_alt is used in calls but not in baseline.
# Reference sequence chr8_KI270817v1_alt is used in calls but not in baseline.
# Reference sequence chr8_KI270816v1_alt is used in calls but not in baseline.
# Reference sequence chr8_KI270815v1_alt is used in calls but not in baseline.
# Reference sequence chr9_GL383539v1_alt is used in calls but not in baseline.
# Reference sequence chr9_GL383540v1_alt is used in calls but not in baseline.
# Reference sequence chr9_GL383541v1_alt is used in calls but not in baseline.
# Reference sequence chr9_GL383542v1_alt is used in calls but not in baseline.
# Reference sequence chr9_KI270823v1_alt is used in calls but not in baseline.
# Reference sequence chr10_GL383545v1_alt is used in calls but not in baseline.
# Reference sequence chr10_KI270824v1_alt is used in calls but not in baseline.
# Reference sequence chr10_GL383546v1_alt is used in calls but not in baseline.
# Reference sequence chr10_KI270825v1_alt is used in calls but not in baseline.
# Reference sequence chr11_KI270832v1_alt is used in calls but not in baseline.
# Reference sequence chr11_KI270830v1_alt is used in calls but not in baseline.
# Reference sequence chr11_KI270831v1_alt is used in calls but not in baseline.
# Reference sequence chr11_KI270829v1_alt is used in calls but not in baseline.
# Reference sequence chr11_GL383547v1_alt is used in calls but not in baseline.
# Reference sequence chr11_JH159136v1_alt is used in calls but not in baseline.
# Reference sequence chr11_JH159137v1_alt is used in calls but not in baseline.
# Reference sequence chr11_KI270827v1_alt is used in calls but not in baseline.
# Reference sequence chr11_KI270826v1_alt is used in calls but not in baseline.
# Reference sequence chr12_GL877875v1_alt is used in calls but not in baseline.
# Reference sequence chr12_GL877876v1_alt is used in calls but not in baseline.
# Reference sequence chr12_KI270837v1_alt is used in calls but not in baseline.
# Reference sequence chr12_GL383549v1_alt is used in calls but not in baseline.
# Reference sequence chr12_KI270835v1_alt is used in calls but not in baseline.
# Reference sequence chr12_GL383550v2_alt is used in calls but not in baseline.
# Reference sequence chr12_GL383552v1_alt is used in calls but not in baseline.
# Reference sequence chr12_GL383553v2_alt is used in calls but not in baseline.
# Reference sequence chr12_KI270834v1_alt is used in calls but not in baseline.
# Reference sequence chr12_GL383551v1_alt is used in calls but not in baseline.
# Reference sequence chr12_KI270833v1_alt is used in calls but not in baseline.
# Reference sequence chr12_KI270836v1_alt is used in calls but not in baseline.
# Reference sequence chr13_KI270840v1_alt is used in calls but not in baseline.
# Reference sequence chr13_KI270839v1_alt is used in calls but not in baseline.
# Reference sequence chr13_KI270843v1_alt is used in calls but not in baseline.
# Reference sequence chr13_KI270841v1_alt is used in calls but not in baseline.
# Reference sequence chr13_KI270838v1_alt is used in calls but not in baseline.
# Reference sequence chr13_KI270842v1_alt is used in calls but not in baseline.
# Reference sequence chr14_KI270844v1_alt is used in calls but not in baseline.
# Reference sequence chr14_KI270847v1_alt is used in calls but not in baseline.
# Reference sequence chr14_KI270845v1_alt is used in calls but not in baseline.
# Reference sequence chr14_KI270846v1_alt is used in calls but not in baseline.
# Reference sequence chr15_KI270852v1_alt is used in calls but not in baseline.
# Reference sequence chr15_KI270851v1_alt is used in calls but not in baseline.
# Reference sequence chr15_KI270848v1_alt is used in calls but not in baseline.
# Reference sequence chr15_GL383554v1_alt is used in calls but not in baseline.
# Reference sequence chr15_KI270849v1_alt is used in calls but not in baseline.
# Reference sequence chr15_GL383555v2_alt is used in calls but not in baseline.
# Reference sequence chr15_KI270850v1_alt is used in calls but not in baseline.
# Reference sequence chr16_KI270854v1_alt is used in calls but not in baseline.
# Reference sequence chr16_KI270856v1_alt is used in calls but not in baseline.
# Reference sequence chr16_KI270855v1_alt is used in calls but not in baseline.
# Reference sequence chr16_KI270853v1_alt is used in calls but not in baseline.
# Reference sequence chr16_GL383556v1_alt is used in calls but not in baseline.
# Reference sequence chr16_GL383557v1_alt is used in calls but not in baseline.
# Reference sequence chr17_GL383563v3_alt is used in calls but not in baseline.
# Reference sequence chr17_KI270862v1_alt is used in calls but not in baseline.
# Reference sequence chr17_KI270861v1_alt is used in calls but not in baseline.
# Reference sequence chr17_KI270857v1_alt is used in calls but not in baseline.
# Reference sequence chr17_JH159146v1_alt is used in calls but not in baseline.
# Reference sequence chr17_JH159147v1_alt is used in calls but not in baseline.
# Reference sequence chr17_GL383564v2_alt is used in calls but not in baseline.
# Reference sequence chr17_GL000258v2_alt is used in calls but not in baseline.
# Reference sequence chr17_GL383565v1_alt is used in calls but not in baseline.
# Reference sequence chr17_KI270858v1_alt is used in calls but not in baseline.
# Reference sequence chr17_KI270859v1_alt is used in calls but not in baseline.
# Reference sequence chr17_GL383566v1_alt is used in calls but not in baseline.
# Reference sequence chr17_KI270860v1_alt is used in calls but not in baseline.
# Reference sequence chr18_KI270864v1_alt is used in calls but not in baseline.
# Reference sequence chr18_GL383567v1_alt is used in calls but not in baseline.
# Reference sequence chr18_GL383570v1_alt is used in calls but not in baseline.
# Reference sequence chr18_GL383571v1_alt is used in calls but not in baseline.
# Reference sequence chr18_GL383568v1_alt is used in calls but not in baseline.
# Reference sequence chr18_GL383569v1_alt is used in calls but not in baseline.
# Reference sequence chr18_GL383572v1_alt is used in calls but not in baseline.
# Reference sequence chr18_KI270863v1_alt is used in calls but not in baseline.
# Reference sequence chr19_KI270868v1_alt is used in calls but not in baseline.
# Reference sequence chr19_KI270865v1_alt is used in calls but not in baseline.
# Reference sequence chr19_GL383573v1_alt is used in calls but not in baseline.
# Reference sequence chr19_GL383575v2_alt is used in calls but not in baseline.
# Reference sequence chr19_GL383576v1_alt is used in calls but not in baseline.
# Reference sequence chr19_GL383574v1_alt is used in calls but not in baseline.
# Reference sequence chr19_KI270866v1_alt is used in calls but not in baseline.
# Reference sequence chr19_KI270867v1_alt is used in calls but not in baseline.
# Reference sequence chr19_GL949746v1_alt is used in calls but not in baseline.
# Reference sequence chr20_GL383577v2_alt is used in calls but not in baseline.
# Reference sequence chr20_KI270869v1_alt is used in calls but not in baseline.
# Reference sequence chr20_KI270871v1_alt is used in calls but not in baseline.
# Reference sequence chr20_KI270870v1_alt is used in calls but not in baseline.
# Reference sequence chr21_GL383578v2_alt is used in calls but not in baseline.
# Reference sequence chr21_KI270874v1_alt is used in calls but not in baseline.
# Reference sequence chr21_KI270873v1_alt is used in calls but not in baseline.
# Reference sequence chr21_GL383579v2_alt is used in calls but not in baseline.
# Reference sequence chr21_GL383580v2_alt is used in calls but not in baseline.
# Reference sequence chr21_GL383581v2_alt is used in calls but not in baseline.
# Reference sequence chr21_KI270872v1_alt is used in calls but not in baseline.
# Reference sequence chr22_KI270875v1_alt is used in calls but not in baseline.
# Reference sequence chr22_KI270878v1_alt is used in calls but not in baseline.
# Reference sequence chr22_KI270879v1_alt is used in calls but not in baseline.
# Reference sequence chr22_KI270876v1_alt is used in calls but not in baseline.
# Reference sequence chr22_KI270877v1_alt is used in calls but not in baseline.
# Reference sequence chr22_GL383583v2_alt is used in calls but not in baseline.
# Reference sequence chr22_GL383582v2_alt is used in calls but not in baseline.
# Reference sequence chrX_KI270880v1_alt is used in calls but not in baseline.
# Reference sequence chrX_KI270881v1_alt is used in calls but not in baseline.
# Reference sequence chr19_KI270882v1_alt is used in calls but not in baseline.
# Reference sequence chr19_KI270884v1_alt is used in calls but not in baseline.
# Reference sequence chr19_KI270885v1_alt is used in calls but not in baseline.
# Reference sequence chr19_KI270886v1_alt is used in calls but not in baseline.
# Reference sequence chr19_KI270887v1_alt is used in calls but not in baseline.
# Reference sequence chr19_KI270888v1_alt is used in calls but not in baseline.
# Reference sequence chr19_KI270890v1_alt is used in calls but not in baseline.
# Reference sequence chr1_KI270892v1_alt is used in calls but not in baseline.
# Reference sequence chr2_KI270894v1_alt is used in calls but not in baseline.
# Reference sequence chr2_KI270893v1_alt is used in calls but not in baseline.
# Reference sequence chr3_KI270895v1_alt is used in calls but not in baseline.
# Reference sequence chr4_KI270896v1_alt is used in calls but not in baseline.
# Reference sequence chr5_KI270897v1_alt is used in calls but not in baseline.
# Reference sequence chr5_KI270898v1_alt is used in calls but not in baseline.
# Reference sequence chr6_GL000251v2_alt is used in calls but not in baseline.
# Reference sequence chr7_KI270899v1_alt is used in calls but not in baseline.
# Reference sequence chr8_KI270901v1_alt is used in calls but not in baseline.
# Reference sequence chr8_KI270900v1_alt is used in calls but not in baseline.
# Reference sequence chr11_KI270902v1_alt is used in calls but not in baseline.
# Reference sequence chr11_KI270903v1_alt is used in calls but not in baseline.
# Reference sequence chr12_KI270904v1_alt is used in calls but not in baseline.
# Reference sequence chr15_KI270906v1_alt is used in calls but not in baseline.
# Reference sequence chr15_KI270905v1_alt is used in calls but not in baseline.
# Reference sequence chr17_KI270907v1_alt is used in calls but not in baseline.
# Reference sequence chr17_KI270910v1_alt is used in calls but not in baseline.
# Reference sequence chr17_KI270909v1_alt is used in calls but not in baseline.
# Reference sequence chr17_JH159148v1_alt is used in calls but not in baseline.
# Reference sequence chr17_KI270908v1_alt is used in calls but not in baseline.
# Reference sequence chr18_KI270912v1_alt is used in calls but not in baseline.
# Reference sequence chr18_KI270911v1_alt is used in calls but not in baseline.
# Reference sequence chr19_GL949747v2_alt is used in calls but not in baseline.
# Reference sequence chr22_KB663609v1_alt is used in calls but not in baseline.
# Reference sequence chrX_KI270913v1_alt is used in calls but not in baseline.
# Reference sequence chr19_KI270914v1_alt is used in calls but not in baseline.
# Reference sequence chr19_KI270916v1_alt is used in calls but not in baseline.
# Reference sequence chr19_KI270917v1_alt is used in calls but not in baseline.
# Reference sequence chr19_KI270918v1_alt is used in calls but not in baseline.
# Reference sequence chr19_KI270919v1_alt is used in calls but not in baseline.
# Reference sequence chr19_KI270920v1_alt is used in calls but not in baseline.
# Reference sequence chr19_KI270921v1_alt is used in calls but not in baseline.
# Reference sequence chr19_KI270922v1_alt is used in calls but not in baseline.
# Reference sequence chr19_KI270923v1_alt is used in calls but not in baseline.
# Reference sequence chr3_KI270924v1_alt is used in calls but not in baseline.
# Reference sequence chr4_KI270925v1_alt is used in calls but not in baseline.
# Reference sequence chr6_GL000252v2_alt is used in calls but not in baseline.
# Reference sequence chr8_KI270926v1_alt is used in calls but not in baseline.
# Reference sequence chr11_KI270927v1_alt is used in calls but not in baseline.
# Reference sequence chr19_GL949748v2_alt is used in calls but not in baseline.
# Reference sequence chr22_KI270928v1_alt is used in calls but not in baseline.
# Reference sequence chr19_KI270929v1_alt is used in calls but not in baseline.
# Reference sequence chr19_KI270930v1_alt is used in calls but not in baseline.
# Reference sequence chr19_KI270932v1_alt is used in calls but not in baseline.
# Reference sequence chr19_GL000209v2_alt is used in calls but not in baseline.
# Reference sequence chr3_KI270934v1_alt is used in calls but not in baseline.
# Reference sequence chr6_GL000253v2_alt is used in calls but not in baseline.
# Reference sequence chr19_GL949749v2_alt is used in calls but not in baseline.
# Reference sequence chr3_KI270935v1_alt is used in calls but not in baseline.
# Reference sequence chr6_GL000254v2_alt is used in calls but not in baseline.
# Reference sequence chr19_GL949750v2_alt is used in calls but not in baseline.
# Reference sequence chr3_KI270936v1_alt is used in calls but not in baseline.
# Reference sequence chr6_GL000255v2_alt is used in calls but not in baseline.
# Reference sequence chr19_GL949751v2_alt is used in calls but not in baseline.
# Reference sequence chr3_KI270937v1_alt is used in calls but not in baseline.
# Reference sequence chr6_GL000256v2_alt is used in calls but not in baseline.
# Reference sequence chr19_GL949752v1_alt is used in calls but not in baseline.
# Reference sequence chr6_KI270758v1_alt is used in calls but not in baseline.
# Reference sequence chr19_GL949753v2_alt is used in calls but not in baseline.
# Reference sequence chr19_KI270938v1_alt is used in calls but not in baseline.
# Reference sequence HLA-B*59:01:01:01 is used in calls but not in baseline.
# Reference sequence HLA-DQA1*01:03:01:01 is used in calls but not in baseline.
# Reference sequence HLA-DQA1*01:03:01:02 is used in calls but not in baseline.
# Reference sequence HLA-DQA1*01:04:01:02 is used in calls but not in baseline.
# Reference sequence HLA-DQA1*04:01:02:01 is used in calls but not in baseline.
# Reference sequence HLA-DQA1*05:03 is used in calls but not in baseline.
# Reference sequence HLA-DQB1*05:03:01:01 is used in calls but not in baseline.
# Reference sequence HLA-DRB1*01:02:01 is used in calls but not in baseline.
# Reference sequence HLA-DRB1*07:01:01:01 is used in calls but not in baseline.
# Reference sequence HLA-DRB1*07:01:01:02 is used in calls but not in baseline.
# Reference sequence HLA-DRB1*09:21 is used in calls but not in baseline.
# Reference sequence HLA-DRB1*10:01:01 is used in calls but not in baseline.
# Reference sequence HLA-DRB1*11:04:01 is used in calls but not in baseline.
# Reference sequence HLA-DRB1*12:01:01 is used in calls but not in baseline.
# Reference sequence HLA-DRB1*12:17 is used in calls but not in baseline.
# Reference sequence HLA-DRB1*13:02:01 is used in calls but not in baseline.
# Reference sequence HLA-DRB1*15:01:01:01 is used in calls but not in baseline.
# Reference sequence HLA-DRB1*15:01:01:02 is used in calls but not in baseline.
# Reference sequence HLA-DRB1*15:02:01 is used in calls but not in baseline.
# Reference sequence HLA-DRB1*15:03:01:01 is used in calls but not in baseline.
# There were 480 variants not thresholded in ROC data files due to missing or invalid GQ (FORMAT) values.

# %% [markdown]
# ### Gather GIAB-comparison RTG summary files

# %%
summary_giab_files = !find scratch/HG001*-giab_vs_n16_{dragen,sentieon,gatk} -name summary.txt
summary_giab_files
# Out:
# ['scratch/HG001_vs_4249-JW-10_combined-giab_vs_n16_dragen/summary.txt',
#  'scratch/HG001_vs_4249-JW-14_combined-giab_vs_n16_dragen/summary.txt',
#  'scratch/HG001_vs_4249-JW-16_combined-giab_vs_n16_dragen/summary.txt',
#  'scratch/HG001_vs_4249-JW-17_combined-giab_vs_n16_dragen/summary.txt',
#  'scratch/HG001_vs_4249-JW-18_combined-giab_vs_n16_dragen/summary.txt',
#  'scratch/HG001_vs_4249-JW-19_combined-giab_vs_n16_dragen/summary.txt',
#  'scratch/HG001_vs_4249-JW-23_combined-giab_vs_n16_dragen/summary.txt',
#  'scratch/HG001_vs_4249-JW-25_combined-giab_vs_n16_dragen/summary.txt',
#  'scratch/HG001_vs_4249-JW-27_combined-giab_vs_n16_dragen/summary.txt',
#  'scratch/HG001_vs_4249-JW-30_combined-giab_vs_n16_dragen/summary.txt',
#  'scratch/HG001_vs_4249-JW-32_combined-giab_vs_n16_dragen/summary.txt',
#  'scratch/HG001_vs_4249-JW-36_combined-giab_vs_n16_dragen/summary.txt',
#  'scratch/HG001_vs_4249-JW-38_combined-giab_vs_n16_dragen/summary.txt',
#  'scratch/HG001_vs_4249-JW-40_combined-giab_vs_n16_dragen/summary.txt',
#  'scratch/HG001_vs_4249-JW-42_combined-giab_vs_n16_dragen/summary.txt',
#  'scratch/HG001_vs_4249-JW-43_combined-giab_vs_n16_dragen/summary.txt',
#  'scratch/HG001_vs_NA12878-Bulk2-merged-n450x10e6-giab_vs_n16_dragen/summary.txt',
#  'scratch/HG001_vs_4249-JW-10-giab_vs_n16_sentieon/summary.txt',
#  'scratch/HG001_vs_4249-JW-14-giab_vs_n16_sentieon/summary.txt',
#  'scratch/HG001_vs_4249-JW-16-giab_vs_n16_sentieon/summary.txt',
#  'scratch/HG001_vs_4249-JW-17-giab_vs_n16_sentieon/summary.txt',
#  'scratch/HG001_vs_4249-JW-18-giab_vs_n16_sentieon/summary.txt',
#  'scratch/HG001_vs_4249-JW-19-giab_vs_n16_sentieon/summary.txt',
#  'scratch/HG001_vs_4249-JW-23-giab_vs_n16_sentieon/summary.txt',
#  'scratch/HG001_vs_4249-JW-25-giab_vs_n16_sentieon/summary.txt',
#  'scratch/HG001_vs_4249-JW-27-giab_vs_n16_sentieon/summary.txt',
#  'scratch/HG001_vs_4249-JW-30-giab_vs_n16_sentieon/summary.txt',
#  'scratch/HG001_vs_4249-JW-32-giab_vs_n16_sentieon/summary.txt',
#  'scratch/HG001_vs_4249-JW-36-giab_vs_n16_sentieon/summary.txt',
#  'scratch/HG001_vs_4249-JW-38-giab_vs_n16_sentieon/summary.txt',
#  'scratch/HG001_vs_4249-JW-40-giab_vs_n16_sentieon/summary.txt',
#  'scratch/HG001_vs_4249-JW-42-giab_vs_n16_sentieon/summary.txt',
#  'scratch/HG001_vs_4249-JW-43-giab_vs_n16_sentieon/summary.txt',
#  'scratch/HG001_vs_NA12878_Bulk2-giab_vs_n16_sentieon/summary.txt',
#  'scratch/HG001_vs_4249-JW-10-giab_vs_n16_gatk/summary.txt',
#  'scratch/HG001_vs_4249-JW-14-giab_vs_n16_gatk/summary.txt',
#  'scratch/HG001_vs_4249-JW-16-giab_vs_n16_gatk/summary.txt',
#  'scratch/HG001_vs_4249-JW-17-giab_vs_n16_gatk/summary.txt',
#  'scratch/HG001_vs_4249-JW-18-giab_vs_n16_gatk/summary.txt',
#  'scratch/HG001_vs_4249-JW-19-giab_vs_n16_gatk/summary.txt',
#  'scratch/HG001_vs_4249-JW-23-giab_vs_n16_gatk/summary.txt',
#  'scratch/HG001_vs_4249-JW-25-giab_vs_n16_gatk/summary.txt',
#  'scratch/HG001_vs_4249-JW-27-giab_vs_n16_gatk/summary.txt',
#  'scratch/HG001_vs_4249-JW-30-giab_vs_n16_gatk/summary.txt',
#  'scratch/HG001_vs_4249-JW-32-giab_vs_n16_gatk/summary.txt',
#  'scratch/HG001_vs_4249-JW-36-giab_vs_n16_gatk/summary.txt',
#  'scratch/HG001_vs_4249-JW-38-giab_vs_n16_gatk/summary.txt',
#  'scratch/HG001_vs_4249-JW-40-giab_vs_n16_gatk/summary.txt',
#  'scratch/HG001_vs_4249-JW-42-giab_vs_n16_gatk/summary.txt',
#  'scratch/HG001_vs_4249-JW-43-giab_vs_n16_gatk/summary.txt',
#  'scratch/HG001_vs_NA12878_Bulk2-giab_vs_n16_gatk/summary.txt']

# %%
df_list = []
for _summary_file in summary_giab_files:
    comparison_dir_name = _summary_file.split("/")[1]
    sample_name = re.sub("HG001_vs_(.+)-giab_.+", "\\1", comparison_dir_name)
    sample_name = re.sub("_combined", "", sample_name)
    sample_name = re.sub("NA12878-Bulk2-merged-n450x10e6", "NA12878_Bulk2", sample_name)
    platform = re.sub("^.+_", "", comparison_dir_name)
    temp_df = pd.read_csv(_summary_file, skiprows=2, sep = "[\t ]+", header = None, names=["Threshold","True-pos-baseline","True-pos-call","False-pos","False-neg","Precision","Sensitivity","F-measure"]).tail(1)
    temp_df['sample_name'] = sample_name
    temp_df['platform'] = platform
    df_list.append(temp_df)
rtg_giab_summary_df = pd.concat(df_list)
rtg_giab_summary_df
# Out:
# /home/rcarter/anacon3/lib/python3.7/site-packages/ipykernel_launcher.py:8: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   Threshold  True-pos-baseline  True-pos-call  False-pos  False-neg  \
# 1      None            2890792        2890754     947599     728679
# 1      None            2956463        2956426     948866     663008
# 1      None            2887412        2887374     928012     732059
# 1      None            2918886        2918857     948085     700585
# 1      None            2999233        2999200     971792     620238
# 1      None            2972312        2972274     979068     647159
# 1      None            2668004        2667967     900548     951467
# 1      None            2996862        2996818     991578     622609
# 1      None            2780062        2780031     938845     839409
# 1      None            2760285        2760250     922241     859186
# 1      None            2738029        2737998     925548     881442
# 1      None            2282538        2282507     813870    1336933
# 1      None            2906935        2906899     955167     712536
# 1      None            2909087        2909046     970968     710384
# 1      None            2935634        2935599     936298     683837
# 1      None            2847231        2847196     932107     772240
# 1      None            3056563        3056524     890290     562908
# 1      None            2842006        2841970     622667     777465
# 1      None            2907420        2907386     636023     712051
# 1      None            2788006        2787973     611920     831465
# 1      None            2822506        2822475     616923     796965
# 1      None            2906151        2906114     631392     713320
# 1      None            2920740        2920707     640651     698731
# 1      None            2617020        2616988     587750    1002451
# 1      None            2948151        2948115     639722     671320
# 1      None            2725349        2725318     601034     894122
# 1      None            2710032        2710002     597293     909439
# 1      None            2684973        2684941     594708     934498
# 1      None            2229418        2229385     504512    1390053
# 1      None            2854640        2854605     616926     764831
# 1      None            2853888        2853854     619406     765583
# 1      None            2855087        2855051     619584     764384
# 1      None            2767191        2767158     600212     852280
# 1      None            3047523        3047483     673274     571948
# 1      None            2806264        2806229     558406     813207
# 1      None            2872912        2872878     575870     746559
# 1      None            2742167        2742135     545104     877304
# 1      None            2784948        2784915     556352     834523
# 1      None            2868277        2868246     567827     751194
# 1      None            2884808        2884774     577266     734663
# 1      None            2583926        2583901     525895    1035545
# 1      None            2911471        2911433     574926     708000
# 1      None            2689722        2689689     539210     929749
# 1      None            2675908        2675875     536464     943563
# 1      None            2650764        2650733     533001     968707
# 1      None            2198602        2198573     448221    1420869
# 1      None            2819254        2819219     557276     800217
# 1      None            2818749        2818714     557601     800722
# 1      None            2818238        2818210     556059     801233
# 1      None            2731382        2731350     537960     888089
# 1      None            2975615        2975573     573673     643856
#
#    Precision  Sensitivity  F-measure    sample_name  platform
# 1     0.7531       0.7987     0.7752     4249-JW-10    dragen
# 1     0.7570       0.8168     0.7858     4249-JW-14    dragen
# 1     0.7568       0.7977     0.7767     4249-JW-16    dragen
# 1     0.7548       0.8064     0.7798     4249-JW-17    dragen
# 1     0.7553       0.8286     0.7903     4249-JW-18    dragen
# 1     0.7522       0.8212     0.7852     4249-JW-19    dragen
# 1     0.7476       0.7371     0.7423     4249-JW-23    dragen
# 1     0.7514       0.8280     0.7878     4249-JW-25    dragen
# 1     0.7475       0.7681     0.7577     4249-JW-27    dragen
# 1     0.7496       0.7626     0.7560     4249-JW-30    dragen
# 1     0.7474       0.7565     0.7519     4249-JW-32    dragen
# 1     0.7372       0.6306     0.6797     4249-JW-36    dragen
# 1     0.7527       0.8031     0.7771     4249-JW-38    dragen
# 1     0.7498       0.8037     0.7758     4249-JW-40    dragen
# 1     0.7582       0.8111     0.7837     4249-JW-42    dragen
# 1     0.7534       0.7866     0.7696     4249-JW-43    dragen
# 1     0.7744       0.8445     0.8079  NA12878_Bulk2    dragen
# 1     0.8203       0.7852     0.8024     4249-JW-10  sentieon
# 1     0.8205       0.8033     0.8118     4249-JW-14  sentieon
# 1     0.8200       0.7703     0.7944     4249-JW-16  sentieon
# 1     0.8206       0.7798     0.7997     4249-JW-17  sentieon
# 1     0.8215       0.8029     0.8121     4249-JW-18  sentieon
# 1     0.8201       0.8070     0.8135     4249-JW-19  sentieon
# 1     0.8166       0.7230     0.7670     4249-JW-23  sentieon
# 1     0.8217       0.8145     0.8181     4249-JW-25  sentieon
# 1     0.8193       0.7530     0.7847     4249-JW-27  sentieon
# 1     0.8194       0.7487     0.7825     4249-JW-30  sentieon
# 1     0.8187       0.7418     0.7783     4249-JW-32  sentieon
# 1     0.8155       0.6160     0.7018     4249-JW-36  sentieon
# 1     0.8223       0.7887     0.8051     4249-JW-38  sentieon
# 1     0.8217       0.7885     0.8047     4249-JW-40  sentieon
# 1     0.8217       0.7888     0.8049     4249-JW-42  sentieon
# 1     0.8218       0.7645     0.7921     4249-JW-43  sentieon
# 1     0.8190       0.8420     0.8304  NA12878_Bulk2  sentieon
# 1     0.8340       0.7753     0.8036     4249-JW-10      gatk
# 1     0.8330       0.7937     0.8129     4249-JW-14      gatk
# 1     0.8342       0.7576     0.7941     4249-JW-16      gatk
# 1     0.8335       0.7694     0.8002     4249-JW-17      gatk
# 1     0.8347       0.7925     0.8131     4249-JW-18      gatk
# 1     0.8333       0.7970     0.8147     4249-JW-19      gatk
# 1     0.8309       0.7139     0.7680     4249-JW-23      gatk
# 1     0.8351       0.8044     0.8195     4249-JW-25      gatk
# 1     0.7548       0.8064     0.7798     4249-JW-17    dragen
# 1     0.7553       0.8286     0.7903     4249-JW-18    dragen
# 1     0.7522       0.8212     0.7852     4249-JW-19    dragen
# 1     0.7476       0.7371     0.7423     4249-JW-23    dragen
# 1     0.7514       0.8280     0.7878     4249-JW-25    dragen
# 1     0.7475       0.7681     0.7577     4249-JW-27    dragen
# 1     0.7496       0.7626     0.7560     4249-JW-30    dragen
# 1     0.7474       0.7565     0.7519     4249-JW-32    dragen
# 1     0.7372       0.6306     0.6797     4249-JW-36    dragen
# 1     0.7527       0.8031     0.7771     4249-JW-38    dragen
# 1     0.7498       0.8037     0.7758     4249-JW-40    dragen
# 1     0.7582       0.8111     0.7837     4249-JW-42    dragen
# 1     0.7534       0.7866     0.7696     4249-JW-43    dragen
# 1     0.7744       0.8445     0.8079  NA12878_Bulk2    dragen
# 1     0.8203       0.7852     0.8024     4249-JW-10  sentieon
# 1     0.8205       0.8033     0.8118     4249-JW-14  sentieon
# 1     0.8200       0.7703     0.7944     4249-JW-16  sentieon
# 1     0.8206       0.7798     0.7997     4249-JW-17  sentieon
# 1     0.8215       0.8029     0.8121     4249-JW-18  sentieon
# 1     0.8201       0.8070     0.8135     4249-JW-19  sentieon
# 1     0.8166       0.7230     0.7670     4249-JW-23  sentieon
# 1     0.8217       0.8145     0.8181     4249-JW-25  sentieon
# 1     0.8193       0.7530     0.7847     4249-JW-27  sentieon
# 1     0.8194       0.7487     0.7825     4249-JW-30  sentieon
# 1     0.8187       0.7418     0.7783     4249-JW-32  sentieon
# 1     0.8155       0.6160     0.7018     4249-JW-36  sentieon
# 1     0.8223       0.7887     0.8051     4249-JW-38  sentieon
# 1     0.8217       0.7885     0.8047     4249-JW-40  sentieon
# 1     0.8217       0.7888     0.8049     4249-JW-42  sentieon
# 1     0.8218       0.7645     0.7921     4249-JW-43  sentieon
# 1     0.8190       0.8420     0.8304  NA12878_Bulk2  sentieon
# 1     0.8340       0.7753     0.8036     4249-JW-10      gatk
# 1     0.8330       0.7937     0.8129     4249-JW-14      gatk
# 1     0.8342       0.7576     0.7941     4249-JW-16      gatk
# 1     0.8335       0.7694     0.8002     4249-JW-17      gatk
# 1     0.8347       0.7925     0.8131     4249-JW-18      gatk
# 1     0.8333       0.7970     0.8147     4249-JW-19      gatk
# 1     0.8309       0.7139     0.7680     4249-JW-23      gatk
# 1     0.8351       0.8044     0.8195     4249-JW-25      gatk
# 1     0.8330       0.7431     0.7855     4249-JW-27      gatk
# 1     0.8330       0.7393     0.7834     4249-JW-30      gatk
# 1     0.8326       0.7324     0.7793     4249-JW-32      gatk
# 1     0.8307       0.6074     0.7017     4249-JW-36      gatk
# 1     0.8350       0.7789     0.8060     4249-JW-38      gatk
# 1     0.8348       0.7788     0.8058     4249-JW-40      gatk
# 1     0.8352       0.7786     0.8059     4249-JW-42      gatk
# 1     0.8355       0.7546     0.7930     4249-JW-43      gatk
# 1     0.8384       0.8221     0.8302  NA12878_Bulk2      gatk
